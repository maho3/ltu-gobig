# %% [markdown]
# ## Load and apply inference models
# This notebook loads trained inference models from the outputs of `cmass.infer.train`, plots their prediction performance, and applies them to new test data.

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

import os
from os.path import join
import pickle
import json
import h5py
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.style.use('../../style.mcstyle')   # noqa
import numpy as np
import torch
import seaborn as sns
import pandas as pd
import warnings
from tqdm import tqdm

# Suppress warnings
warnings.filterwarnings('ignore')

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("CUDA is available. Using GPU.")
else:
    device = torch.device("cpu")
    print("CUDA is not available. Using CPU.")
# Out:
# CUDA is not available. Using CPU.

# %% [markdown]
# ## Load a model

# %%
wdir = '/anvil/scratch/x-mho1/cmass-ili'
cosmonames = [r'$\Omega_m$', r'$\Omega_b$', r'$h$', r'$n_s$', r'$\sigma_8$']
hodnames = [r'$\alpha$', r'$\log M_0$', r'$\log M_1$',
            r'$\log M_{\min}$', r'$\sigma_{\log M}$']
names = cosmonames# +hodnames

# Specify model configuration
nbody = 'quijotelike'
sim = 'fastpm'
save_dir = join(wdir, nbody, sim, 'models')

# %%
# Specify data dtype
tracer = 'halo'
summaries = ['Pk0', 'Pk2', 'Pk4']
summary = '+'.join(summaries)
kmax = 0.4
modelpath = join(save_dir, tracer, summary, f'kmax-{kmax}')
os.listdir(modelpath)
# Out:
# ['x_val.npy',
#  'posterior.pkl',
#  'true_logprobs.npy',
#  'ids_test.npy',
#  'theta_train.npy',
#  'plot_coverage.jpg',
#  'theta_test.npy',
#  'x_test.npy',
#  'nets',
#  'plot_true_logprobs.jpg',
#  'ids_train.npy',
#  'theta_val.npy',
#  'ranks_histogram.jpg',
#  'plot_single_posterior.jpg',
#  'x_train.npy',
#  'plot_TARP.jpg',
#  'plot_predictions.jpg',
#  'ids_val.npy',
#  'posterior_samples.npy']

# %%
# # Load training history
# summary_file = join(modelpath, 'summary.json')
# with open(summary_file, 'r') as f:
#     history = json.load(f)
# f, ax = plt.subplots(1, 1, figsize=(12, 4))
# for i in range(len(history)):
#     ax.plot(history[i]['training_log_probs'],
#             label=f'Training {i}', c=f'C{i}', ls='--')
#     ax.plot(history[i]['validation_log_probs'],
#             label=f'Validation {i}', c=f'C{i}')
# ax.set(xlabel='Epoch', ylabel='Log Probability')
# ax.legend()
# ax.set_ylim(-5, 15)

# %%
# Load predictions
xtest = np.load(join(modelpath, 'x_test.npy'))
ytest = np.load(join(modelpath, 'theta_test.npy'))
samps = np.load(join(modelpath, 'posterior_samples.npy'))
percs = np.percentile(samps, [16, 50, 84], axis=0)

yrange = np.stack([
    ytest.min(axis=0),
    ytest.max(axis=0)
], axis=1)

# %%
plt.plot(xtest[0])

# %%
ss = 3

N = len(names)
f, axs = plt.subplots(2, N//2+1, figsize=(20, 8), gridspec_kw=dict(wspace=0.3))
axs = axs.flatten()

for i, ax in enumerate(axs[:-1]):
    ax.plot(yrange[i], yrange[i], 'r--')
    ax.plot(ytest[::ss, i], percs[1, ::ss, i], 'k.')
    ax.errorbar(ytest[::ss, i], percs[1, ::ss, i], yerr=[percs[1, ::ss, i]-percs[0, ::ss, i],
                percs[2, ::ss, i]-percs[1, ::ss, i]], fmt='none', ecolor='k', elinewidth=1)
    ax.set(xlabel=f'True {names[i]}', ylabel=f'Predicted {names[i]}')
axs[-1].axis('off')
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
# these functions load pickled torch modules
# if the model was trained on GPU, this will ensure safe loading to CPU
# TODO: update ltu-ili so this is already handled...

import torch
import io


class CPU_Unpickler(pickle.Unpickler):
    def find_class(self, module, name):
        if module == 'torch.storage' and name == '_load_from_bytes':
            return lambda b: torch.load(io.BytesIO(b), map_location='cpu')
        else:
            return super().find_class(module, name)


def load_posterior(modeldir):
    with open(join(modeldir, 'posterior.pkl'), 'rb') as f:
        ensemble = CPU_Unpickler(f).load()
    ensemble = ensemble.to(device)
    for p in ensemble.posteriors:
        p.to(device)
    return ensemble


posterior = load_posterior(modelpath)

# %%
# Predict on a random test point
ind = 0
x0 = torch.Tensor(xtest[ind]).to(device)
y0 = ytest[ind]
samp0 = posterior.sample(x=x0, shape=(2000,))
samp0 = pd.DataFrame(samp0, columns=names)


def plot_true_vals(grid, true_vals, **kwargs):
    for i, val in enumerate(true_vals):
        grid.diag_axes[i].axvline(val, **kwargs)
        for j, ax in enumerate(grid.axes[i, :i]):
            if ax:
                ax.axvline(true_vals[j], **kwargs)
                ax.axhline(val, **kwargs)
                ax.plot(true_vals[j], val, 'o', **kwargs)


g = sns.pairplot(
    samp0,
    vars=names,
    kind='hist',
    corner=True,
    height=1.5
    # plot_kws={'alpha': 0.5, 'levels': [0.05, 0.36, 1], 'fill': True},  # for kde plot
)

plot_true_vals(g, y0, color='r', lw=1)
# Out:
# INFO:root:Sampling models with [289, 268, 212, 211, 191, 187, 171, 163, 160, 153] samples each.
# Drawing 289 posterior samples: 550it [00:03, 174.84it/s]
# Drawing 268 posterior samples: 472it [00:05, 79.35it/s]
# Drawing 212 posterior samples: 344it [00:03, 105.43it/s]
# Drawing 211 posterior samples: 377it [00:04, 88.43it/s]
# Drawing 191 posterior samples: 346it [00:05, 66.60it/s]
# Drawing 187 posterior samples: 342it [00:02, 159.73it/s]
# Drawing 171 posterior samples: 264it [00:00, 59986.80it/s]
# Drawing 163 posterior samples: 227it [00:00, 11105.23it/s]
# Drawing 160 posterior samples: 283it [00:00, 5183.44it/s]
# Drawing 153 posterior samples: 198it [00:00, 4772.36it/s]

# %% [markdown]
# ## Load an observed summary

# %%
# Load observed data
nbody = 'quijote'
sim = 'nbody'
save_dir = join(wdir, nbody, sim, 'models')
modelpath = join(save_dir, tracer, summary, f'kmax-{kmax}')

xobs = np.load(join(modelpath, 'x_test.npy'))
yobs = np.load(join(modelpath, 'theta_test.npy'))

# %%
# from cmass.infer.loaders import load_Pk, load_Bk, load_lc_Pk, get_cosmo

# # Load an observed summary
# nbody = 'quijote'
# sim = 'nbody'
# L, N = 1000, 128
# lhid = 131
# # summaries = ['Pk0', 'Pk2']

# simpath = join(wdir, nbody, sim, f'L{L}-N{N}', f'{lhid}')

# diagfile = join(simpath, 'diag', 'halos.h5')
# summ = {}
# if 'Pk0' in summaries:
#     summ |= load_Pk(diagfile, 0.666667)
# if ('Bk0' in summaries) or ('Qk0' in summaries):
#     summ |= load_Bk(diagfile, 0.666667)
# truecosmo = get_cosmo(simpath)

# trueparams = truecosmo
# summ = {k: [v] for k, v in summ.items()}

# %%
# # Preprocess the summary
# from cmass.infer.loaders import preprocess_Pk, preprocess_Bk
# xin = []
# for s in summaries:
#     if s == 'Pk0':
#         xs = preprocess_Pk(summ[s], kmax, monopole=True)
#     elif 'Pk' in s:
#         xs = preprocess_Pk(summ[s], kmax, monopole=False, norm=summ['Pk0'])
#     elif 'Bk' in s or 'Qk' in s:
#         xs = preprocess_Bk(summ[s], kmax)
#     else:
#         raise NotImplementedError
#     xin.append(xs)
# xin = np.concatenate(xin, axis=-1)

# %%
len(xtest), len(ytest), len(xobs)
# Out:
# (200, 200, 200)

# %%
import matplotlib.colors as mcolors

ss = 10
ind = 0

f, axs = plt.subplots(2, 1, figsize=(10, 10), sharex=True, 
                      gridspec_kw=dict(hspace=0., height_ratios=[1, 0.3]))

par = ytest[:, 0]
cmap = plt.get_cmap('viridis')
norm = mcolors.Normalize(vmin=par.min(), vmax=par.max())

ax = axs[0]
for i in range(0, len(xtest), ss):
    ax.plot(xtest[i], color=cmap(norm(par[i])))
ax.plot(xobs[ind], 'r-', lw=2)
ax.set(ylabel=r'$x$')

ax  = axs[1]
for i in range(0, len(xtest), ss):
    ax.plot((xtest[i]-xobs[i])/np.std(xtest, axis=0), color=cmap(norm(par[i])))
ax.axhline(0, c='k', ls='--', lw=1)
ax.set(xlabel='k', ylabel=r'$(x - x_{\rm obs}$)/std$(x)$')

cbar = f.colorbar(mpl.cm.ScalarMappable(norm=norm, cmap=cmap), 
                  ax=axs, orientation='horizontal')
cbar.set_label(r'$\Omega_m$')

# %%
import matplotlib.colors as mcolors

ss = 10
ind = 0

f, axs = plt.subplots(2, 1, figsize=(10, 10), sharex=True, 
                      gridspec_kw=dict(hspace=0., height_ratios=[1, 0.3]))

par = ytest[:, 4]
cmap = plt.get_cmap('viridis')
norm = mcolors.Normalize(vmin=par.min(), vmax=par.max())

ax = axs[0]
for i in range(0, len(xtest), ss):
    ax.plot(xtest[i], color=cmap(norm(par[i])))
ax.plot(xobs[ind], 'r-', lw=2)
ax.set(ylabel=r'$x$')

ax  = axs[1]
for i in range(0, len(xtest), ss):
    ax.plot((xtest[i]-xobs[i])/np.std(xtest, axis=0), color=cmap(norm(par[i])))
ax.axhline(0, c='k', ls='--', lw=1)
ax.set(xlabel='k', ylabel=r'$(x - x_{\rm obs}$)/std$(x)$')

cbar = f.colorbar(mpl.cm.ScalarMappable(norm=norm, cmap=cmap), 
                  ax=axs, orientation='horizontal')
cbar.set_label(r'$\sigma_8$')

# %%
# Predict on a random test point
ind = 11
samp0 = posterior.sample(x=xobs[ind], shape=(1999,)).to('cpu')
samp0 = pd.DataFrame(samp0, columns=names)


def plot_true_vals(grid, true_vals, **kwargs):
    for i, val in enumerate(true_vals):
        grid.diag_axes[i].axvline(val, **kwargs)
        for j, ax in enumerate(grid.axes[i, :i]):
            if ax:
                ax.axvline(true_vals[j], **kwargs)
                ax.axhline(val, **kwargs)
                ax.plot(true_vals[j], val, 'o', **kwargs)


def set_boundaries(grid, prior_range):
    for i, (x, y) in enumerate(prior_range):
        grid.diag_axes[i].set_xlim(x, y)
        for j, ax in enumerate(grid.axes[i, :i]):
            if ax:
                ax.set_ylim(x, y)
                ax.set_xlim(*prior_range[j])


g = sns.pairplot(
    samp0,
    vars=names,
    kind='kde',
    plot_kws={'alpha': 0.5, 'levels': [
        0.05, 0.36, 1], 'fill': True, 'common_norm': False},
    corner=True,
    height=1.5
    # plot_kws={'alpha': 0.5, 'levels': [0.05, 0.36, 1], 'fill': True},  # for kde plot
)

plot_true_vals(g, yobs[ind], color='r', lw=1)
set_boundaries(g, yrange)
# Out:
# INFO:root:Sampling models with [289, 268, 212, 210, 191, 187, 171, 163, 159, 153] samples each.
# Drawing 289 posterior samples: 528it [00:00, 4467.92it/s]
# Drawing 268 posterior samples: 499it [00:00, 6864.56it/s]
# Drawing 212 posterior samples: 342it [00:00, 9019.21it/s]
# Drawing 210 posterior samples: 390it [00:00, 7910.76it/s]
# Drawing 191 posterior samples: 345it [00:00, 6081.03it/s]
# Drawing 187 posterior samples: 340it [00:00, 7069.20it/s]
# Drawing 171 posterior samples: 200it [00:00, 47084.69it/s]
# Drawing 163 posterior samples: 247it [00:00, 13388.38it/s]
# Drawing 159 posterior samples: 290it [00:00, 5239.51it/s]
# Drawing 153 posterior samples: 247it [00:00, 6572.39it/s]

# %%
# Load literature
import pandas as pd

# ivanov
iva = pd.read_csv(
    '/anvil/scratch/x-mho1/cmass-ili/literature/processed/ivanov.csv')
iva = iva.drop('chain', axis=1)

# simbig
sbpk = pd.read_csv(
    '/anvil/scratch/x-mho1/cmass-ili/literature/processed/simbig_pk.csv')


# our work
ltu = pd.DataFrame(samp0.values[:, :5], columns=iva.columns)

# %%
# Create a pairplot of the samples with specified KDE levels and fill, using latex names as axis labels
import seaborn as sns

iva['type'] = 'Ivanov Pk+Bk 2022 (kmax=0.4)'
ltu['type'] = 'LtU'
sbpk['type'] = 'SimBIG Pk (kmax=0.5)'

out = pd.concat([iva[:len(ltu)], ltu]).reset_index(drop=True)

g = sns.pairplot(
    out,
    hue='type',
    kind='kde',
    plot_kws={'alpha': 0.5, 'levels': [
        0.05, 0.36, 1], 'fill': True, 'common_norm': False},
    corner=True,
    height=1.5  # Adjust the height to make the figure smaller
)
set_boundaries(g, yrange[:5])

# %%
# Create a pairplot of the samples with specified KDE levels and fill, using latex names as axis labels
import seaborn as sns

iva['type'] = 'Ivanov Pk+Bk 2022 (kmax=0.4)'
ltu['type'] = 'LtU'
sbpk['type'] = 'SimBIG Pk (kmax=0.5)'

out = pd.concat([sbpk[:len(ltu)], ltu]).reset_index(drop=True)

g = sns.pairplot(
    out,
    hue='type',
    kind='kde',
    plot_kws={'alpha': 0.5, 'levels': [
        0.05, 0.36, 1], 'fill': True, 'common_norm': False},
    corner=True,
    height=1.5  # Adjust the height to make the figure smaller
)
set_boundaries(g, yrange[:5])

# %% [markdown]
# ## Plot multiple observed summaries

# %%
from cmass.infer.loaders import load_Pk, load_Bk, load_lc_Pk, get_cosmo

# Load an observed summary
nbody = 'abacus'
sim = 'nbody'
L, N = 2000, 256
lhid = 131
# summaries = ['Pk0', 'Pk2']

simpath = join(wdir, nbody, sim, f'L{L}-N{N}', f'{lhid}')

diagfile = join(simpath, 'diag', 'halos.h5')
summ = {}
if 'Pk0' in summaries:
    summ |= load_Pk(diagfile, 0.666667)
if ('Bk0' in summaries) or ('Qk0' in summaries):
    summ |= load_Bk(diagfile, 0.666667)
truecosmo = get_cosmo(simpath)

trueparams = truecosmo
summ = {k: [v] for k, v in summ.items()}

# %%
# Load an observed summary
nbody = 'abacus'
sim = 'nbody'
L, N = 2000, 256
# summaries = ['Pk0', 'Pk2']
from cmass.infer.loaders import get_cosmo

def get_data_vector(lhid):
    simpath = join(wdir, nbody, sim, f'L{L}-N{N}', f'{lhid}')

    diagfile = join(simpath, 'diag', 'halos.h5')
    summ = {}
    if 'Pk0' in summaries:
        summ |= load_Pk(diagfile, 0.666667)
    if ('Bk0' in summaries) or ('Qk0' in summaries):
        summ |= load_Bk(diagfile, 0.666667)
    truecosmo = get_cosmo(simpath)

    trueparams = truecosmo
    summ = {k: [v] for k, v in summ.items()}

    # Preprocess the summary
    from cmass.infer.loaders import preprocess_Pk, preprocess_Bk
    xin = []
    for s in summaries:
        if s == 'Pk0':
            xs = preprocess_Pk(summ[s], kmax, monopole=True)
        elif 'Pk' in s:
            xs = preprocess_Pk(summ[s], kmax, monopole=False, norm=summ['Pk0'])
        elif 'Bk' in s or 'Qk' in s:
            xs = preprocess_Bk(summ[s], kmax)
        else:
            raise NotImplementedError
        xin.append(xs)
    xin = np.concatenate(xin, axis=-1)

    return xin, trueparams

# %%
xins, trues = [], []
for i in range(130, 147):
    xin, true = get_data_vector(i)
    xins.append(xin)
    trues.append(true)

# %%
samps = []
for xin in tqdm(xobs):
    samp = posterior.sample(x=xin, shape=(1000,)).to('cpu')
    samps.append(samp)
# Out:
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 255it [00:00, 5559.85it/s]
#
# Drawing 134 posterior samples: 243it [00:00, 4090.31it/s]
#
# Drawing 106 posterior samples: 170it [00:00, 5505.10it/s]
#
# Drawing 106 posterior samples: 196it [00:00, 4830.90it/s]
#
# Drawing 96 posterior samples: 172it [00:00, 3628.64it/s]
#
# Drawing 94 posterior samples: 156it [00:00, 3566.99it/s]
#
# Drawing 86 posterior samples: 130it [00:00, 33896.53it/s]
#
# Drawing 82 posterior samples: 115it [00:00, 7003.30it/s]
#
# Drawing 80 posterior samples: 142it [00:00, 2929.07it/s]
#
# Drawing 77 posterior samples: 122it [00:00, 3794.46it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 203it [00:00, 4648.56it/s]
#
# Drawing 134 posterior samples: 169it [00:00, 2880.32it/s]
#
# Drawing 106 posterior samples: 119it [00:00, 3973.40it/s]
#
# Drawing 106 posterior samples: 176it [00:00, 4039.52it/s]
#
# Drawing 96 posterior samples: 162it [00:00, 3274.75it/s]
#
# Drawing 94 posterior samples: 151it [00:00, 3674.20it/s]
#
# Drawing 86 posterior samples: 91it [00:00, 16368.54it/s]
#
# Drawing 82 posterior samples: 112it [00:00, 4511.87it/s]
#
# Drawing 80 posterior samples: 137it [00:00, 2910.42it/s]
#
# Drawing 77 posterior samples: 95it [00:00, 3030.29it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 265it [00:00, 5680.38it/s]
#
# Drawing 134 posterior samples: 244it [00:00, 4145.95it/s]
#
# Drawing 106 posterior samples: 170it [00:00, 6023.19it/s]
#
# Drawing 106 posterior samples: 188it [00:00, 4148.25it/s]
#
# Drawing 96 posterior samples: 178it [00:00, 3605.96it/s]
#
# Drawing 94 posterior samples: 163it [00:00, 3763.90it/s]
#
# Drawing 86 posterior samples: 117it [00:00, 31609.25it/s]
#
# Drawing 82 posterior samples: 107it [00:00, 5671.85it/s]
#
# Drawing 80 posterior samples: 142it [00:00, 3050.61it/s]
#
# Drawing 77 posterior samples: 107it [00:00, 3236.53it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 273it [00:00, 6159.57it/s]
#
# Drawing 134 posterior samples: 195it [00:00, 3352.60it/s]
#
# Drawing 106 posterior samples: 173it [00:00, 6033.87it/s]
#
# Drawing 106 posterior samples: 196it [00:00, 4826.47it/s]
#
# Drawing 96 posterior samples: 164it [00:00, 3325.03it/s]
#
# Drawing 94 posterior samples: 178it [00:00, 4493.07it/s]
#
# Drawing 86 posterior samples: 149it [00:00, 40771.87it/s]
#
# Drawing 82 posterior samples: 137it [00:00, 7975.95it/s]
#
# Drawing 80 posterior samples: 151it [00:00, 3308.29it/s]
#
# Drawing 77 posterior samples: 107it [00:00, 3307.64it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 172it [00:00, 3936.19it/s]
#
# Drawing 134 posterior samples: 141it [00:00, 2410.61it/s]
#
# Drawing 106 posterior samples: 137it [00:00, 3322.00it/s]
#
# Drawing 106 posterior samples: 181it [00:00, 4421.36it/s]
#
# Drawing 96 posterior samples: 128it [00:00, 2674.38it/s]
#
# Drawing 94 posterior samples: 114it [00:00, 2846.91it/s]
#
# Drawing 86 posterior samples:   6%|▌         | 5/86 [00:00<00:00, 2498.39it/s]
#
# Drawing 82 posterior samples: 99it [00:00, 5966.21it/s]
#
# Drawing 80 posterior samples: 144it [00:00, 2709.67it/s]
#
# Drawing 77 posterior samples: 109it [00:00, 3459.91it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 269it [00:00, 5825.93it/s]
#
# Drawing 134 posterior samples: 243it [00:00, 4219.43it/s]
#
# Drawing 106 posterior samples: 178it [00:00, 6378.03it/s]
#
# Drawing 106 posterior samples: 195it [00:00, 4721.32it/s]
#
# Drawing 96 posterior samples: 142it [00:00, 2938.10it/s]
#
# Drawing 94 posterior samples: 172it [00:00, 4220.88it/s]
#
# Drawing 86 posterior samples: 116it [00:00, 30958.21it/s]
#
# Drawing 82 posterior samples: 123it [00:00, 7280.75it/s]
#
# Drawing 80 posterior samples: 152it [00:00, 3158.25it/s]
#
# Drawing 77 posterior samples: 121it [00:00, 3663.12it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 275it [00:00, 6278.15it/s]
#
# Drawing 134 posterior samples: 166it [00:00, 2777.40it/s]
#
# Drawing 106 posterior samples: 171it [00:00, 5857.11it/s]
#
# Drawing 106 posterior samples: 190it [00:00, 4549.08it/s]
#
# Drawing 96 posterior samples: 168it [00:00, 3488.94it/s]
#
# Drawing 94 posterior samples: 145it [00:00, 3513.81it/s]
#
# Drawing 86 posterior samples: 122it [00:00, 32877.48it/s]
#
# Drawing 82 posterior samples: 134it [00:00, 8076.40it/s]
#
# Drawing 80 posterior samples: 151it [00:00, 3204.74it/s]
#
# Drawing 77 posterior samples: 87it [00:00, 2641.59it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 272it [00:00, 6066.97it/s]
#
# Drawing 134 posterior samples: 242it [00:00, 4133.77it/s]
#
# Drawing 106 posterior samples: 172it [00:00, 6015.70it/s]
#
# Drawing 106 posterior samples: 198it [00:00, 4706.34it/s]
#
# Drawing 96 posterior samples: 165it [00:00, 3391.99it/s]
#
# Drawing 94 posterior samples: 172it [00:00, 4201.80it/s]
#
# Drawing 86 posterior samples: 133it [00:00, 27753.35it/s]
#
# Drawing 82 posterior samples: 128it [00:00, 7679.57it/s]
#
# Drawing 80 posterior samples: 152it [00:00, 3293.87it/s]
#
# Drawing 77 posterior samples: 118it [00:00, 3609.98it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 252it [00:00, 5907.93it/s]
#
# Drawing 134 posterior samples: 222it [00:00, 3697.64it/s]
#
# Drawing 106 posterior samples: 130it [00:00, 3090.51it/s]
#
#
# Drawing 106 posterior samples: 129it [00:00, 631.62it/s]
#
#
# Drawing 96 posterior samples: 159it [00:00, 833.58it/s]
#
# Drawing 94 posterior samples: 114it [00:00, 2837.52it/s]
#
# Drawing 86 posterior samples: 131it [00:00, 23758.11it/s]
#
# Drawing 82 posterior samples: 104it [00:00, 5777.35it/s]
#
# Drawing 80 posterior samples: 127it [00:00, 1429.59it/s]
#
# Drawing 77 posterior samples: 100%|██████████| 77/77 [00:00<00:00, 2428.57it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 263it [00:00, 5847.07it/s]
#
# Drawing 134 posterior samples: 243it [00:00, 2488.92it/s]
#
# Drawing 106 posterior samples: 144it [00:00, 5401.99it/s]
#
# Drawing 106 posterior samples: 163it [00:00, 3873.60it/s]
#
# Drawing 96 posterior samples: 156it [00:00, 3251.04it/s]
#
# Drawing 94 posterior samples: 163it [00:00, 4036.41it/s]
#
# Drawing 86 posterior samples: 107it [00:00, 28922.51it/s]
#
# Drawing 82 posterior samples: 114it [00:00, 5544.87it/s]
#
# Drawing 80 posterior samples: 152it [00:00, 3014.02it/s]
#
# Drawing 77 posterior samples: 91it [00:00, 3076.91it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 201it [00:00, 3099.95it/s]
#
# Drawing 134 posterior samples: 139it [00:00, 1576.67it/s]
#
# Drawing 106 posterior samples:   6%|▌         | 6/106 [00:00<00:00, 439.27it/s]
#
# Drawing 106 posterior samples: 147it [00:00, 3516.64it/s]
#
# Drawing 96 posterior samples: 97it [00:00, 2040.97it/s]
#
# Drawing 94 posterior samples:  40%|████      | 38/94 [00:00<00:00, 969.54it/s]
#
# Drawing 86 posterior samples: 111it [00:00, 20780.56it/s]
#
# Drawing 82 posterior samples: 86it [00:00, 3571.14it/s]
#
# Drawing 80 posterior samples: 97it [00:00, 1939.95it/s]
#
# Drawing 77 posterior samples:  75%|███████▌  | 58/77 [00:00<00:00, 1287.24it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 269it [00:00, 6179.21it/s]
#
# Drawing 134 posterior samples: 238it [00:00, 4090.53it/s]
#
# Drawing 106 posterior samples: 174it [00:00, 6419.46it/s]
#
# Drawing 106 posterior samples: 201it [00:00, 4884.87it/s]
#
# Drawing 96 posterior samples: 174it [00:00, 3616.76it/s]
#
# Drawing 94 posterior samples: 177it [00:00, 4377.70it/s]
#
# Drawing 86 posterior samples: 116it [00:00, 31831.16it/s]
#
# Drawing 82 posterior samples: 123it [00:00, 7633.91it/s]
#
# Drawing 80 posterior samples: 151it [00:00, 3304.00it/s]
#
# Drawing 77 posterior samples: 124it [00:00, 3850.69it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 252it [00:00, 5557.50it/s]
#
# Drawing 134 posterior samples: 231it [00:00, 4010.23it/s]
#
# Drawing 106 posterior samples: 163it [00:00, 5673.58it/s]
#
# Drawing 106 posterior samples: 177it [00:00, 4434.84it/s]
#
# Drawing 96 posterior samples: 177it [00:00, 3588.97it/s]
#
# Drawing 94 posterior samples: 136it [00:00, 3426.82it/s]
#
# Drawing 86 posterior samples: 114it [00:00, 31286.44it/s]
#
# Drawing 82 posterior samples: 115it [00:00, 5080.10it/s]
#
# Drawing 80 posterior samples: 141it [00:00, 2917.35it/s]
#
# Drawing 77 posterior samples: 107it [00:00, 3578.61it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 280it [00:00, 6376.81it/s]
#
# Drawing 134 posterior samples: 245it [00:00, 4222.73it/s]
#
# Drawing 106 posterior samples: 175it [00:00, 6406.26it/s]
#
# Drawing 106 posterior samples: 197it [00:00, 4672.38it/s]
#
# Drawing 96 posterior samples: 172it [00:00, 3578.60it/s]
#
# Drawing 94 posterior samples: 169it [00:00, 4202.88it/s]
#
# Drawing 86 posterior samples: 144it [00:00, 39772.14it/s]
#
# Drawing 82 posterior samples: 145it [00:00, 8928.24it/s]
#
# Drawing 80 posterior samples: 145it [00:00, 2731.19it/s]
#
# Drawing 77 posterior samples: 128it [00:00, 3959.08it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 271it [00:00, 5384.34it/s]
#
# Drawing 134 posterior samples: 250it [00:00, 4362.74it/s]
#
# Drawing 106 posterior samples: 172it [00:00, 6627.78it/s]
#
# Drawing 106 posterior samples: 198it [00:00, 4931.22it/s]
#
# Drawing 96 posterior samples: 170it [00:00, 3378.46it/s]
#
# Drawing 94 posterior samples: 164it [00:00, 4115.09it/s]
#
# Drawing 86 posterior samples: 122it [00:00, 33383.68it/s]
#
# Drawing 82 posterior samples: 128it [00:00, 7828.62it/s]
#
# Drawing 80 posterior samples: 155it [00:00, 3188.90it/s]
#
# Drawing 77 posterior samples: 112it [00:00, 3681.69it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 263it [00:00, 6294.95it/s]
#
# Drawing 134 posterior samples: 241it [00:00, 4138.61it/s]
#
# Drawing 106 posterior samples: 173it [00:00, 6640.63it/s]
#
# Drawing 106 posterior samples: 203it [00:00, 5137.10it/s]
#
# Drawing 96 posterior samples: 168it [00:00, 3235.14it/s]
#
# Drawing 94 posterior samples: 166it [00:00, 3972.99it/s]
#
# Drawing 86 posterior samples: 142it [00:00, 37205.85it/s]
#
# Drawing 82 posterior samples: 136it [00:00, 7343.18it/s]
#
# Drawing 80 posterior samples: 137it [00:00, 2932.38it/s]
#
# Drawing 77 posterior samples: 105it [00:00, 3080.38it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 241it [00:00, 2877.04it/s]
#
# Drawing 134 posterior samples: 202it [00:00, 3391.53it/s]
#
# Drawing 106 posterior samples: 137it [00:00, 4874.53it/s]
#
# Drawing 106 posterior samples: 185it [00:00, 4448.19it/s]
#
# Drawing 96 posterior samples: 172it [00:00, 3544.00it/s]
#
# Drawing 94 posterior samples: 114it [00:00, 2853.13it/s]
#
# Drawing 86 posterior samples: 122it [00:00, 33030.28it/s]
#
# Drawing 82 posterior samples: 128it [00:00, 7030.05it/s]
#
# Drawing 80 posterior samples: 131it [00:00, 2710.78it/s]
#
# Drawing 77 posterior samples: 105it [00:00, 3325.32it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 158it [00:00, 3717.46it/s]
#
# Drawing 134 posterior samples: 144it [00:00, 2040.30it/s]
#
# Drawing 106 posterior samples:  49%|████▉     | 52/106 [00:00<00:00, 1807.83it/s]
#
# Drawing 106 posterior samples: 152it [00:00, 3773.62it/s]
#
# Drawing 96 posterior samples: 160it [00:00, 3002.97it/s]
#
# Drawing 94 posterior samples: 147it [00:00, 3641.06it/s]
#
# Drawing 86 posterior samples:   8%|▊         | 7/86 [00:00<00:00, 3469.64it/s]
#
# Drawing 82 posterior samples: 107it [00:00, 4136.09it/s]
#
# Drawing 80 posterior samples: 127it [00:00, 2431.64it/s]
#
# Drawing 77 posterior samples: 97it [00:00, 2043.25it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 174it [00:00, 3989.64it/s]
#
# Drawing 134 posterior samples: 182it [00:00, 3026.61it/s]
#
# Drawing 106 posterior samples: 107it [00:00, 2444.69it/s]
#
# Drawing 106 posterior samples: 160it [00:00, 3893.64it/s]
#
# Drawing 96 posterior samples: 166it [00:00, 3361.57it/s]
#
# Drawing 94 posterior samples: 146it [00:00, 3602.21it/s]
#
# Drawing 86 posterior samples:  69%|██████▊   | 59/86 [00:00<00:00, 10593.94it/s]
#
# Drawing 82 posterior samples: 109it [00:00, 4129.56it/s]
#
# Drawing 80 posterior samples: 138it [00:00, 2803.33it/s]
#
# Drawing 77 posterior samples: 110it [00:00, 2220.12it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 271it [00:00, 6106.26it/s]
#
# Drawing 134 posterior samples: 237it [00:00, 3726.87it/s]
#
# Drawing 106 posterior samples: 170it [00:00, 5654.94it/s]
#
# Drawing 106 posterior samples: 192it [00:00, 4674.38it/s]
#
# Drawing 96 posterior samples: 174it [00:00, 3275.99it/s]
#
# Drawing 94 posterior samples: 170it [00:00, 4182.91it/s]
#
# Drawing 86 posterior samples: 127it [00:00, 33976.06it/s]
#
# Drawing 82 posterior samples: 134it [00:00, 8081.51it/s]
#
# Drawing 80 posterior samples: 150it [00:00, 3046.47it/s]
#
# Drawing 77 posterior samples: 123it [00:00, 3756.80it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 189it [00:00, 4245.13it/s]
#
# Drawing 134 posterior samples: 159it [00:00, 2552.90it/s]
#
# Drawing 106 posterior samples: 141it [00:00, 3295.79it/s]
#
# Drawing 106 posterior samples: 171it [00:00, 4036.07it/s]
#
# Drawing 96 posterior samples: 170it [00:00, 3397.38it/s]
#
# Drawing 94 posterior samples: 143it [00:00, 3565.95it/s]
#
# Drawing 86 posterior samples: 101it [00:00, 18658.59it/s]
#
# Drawing 82 posterior samples: 114it [00:00, 4403.02it/s]
#
# Drawing 80 posterior samples: 130it [00:00, 2644.89it/s]
#
# Drawing 77 posterior samples: 86it [00:00, 2701.20it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 252it [00:00, 5816.06it/s]
#
# Drawing 134 posterior samples: 225it [00:00, 3643.14it/s]
#
# Drawing 106 posterior samples: 157it [00:00, 5533.62it/s]
#
# Drawing 106 posterior samples: 172it [00:00, 4214.59it/s]
#
# Drawing 96 posterior samples: 174it [00:00, 3567.82it/s]
#
# Drawing 94 posterior samples: 140it [00:00, 3345.65it/s]
#
# Drawing 86 posterior samples: 98it [00:00, 21381.70it/s]
#
# Drawing 82 posterior samples: 131it [00:00, 8006.15it/s]
#
# Drawing 80 posterior samples: 150it [00:00, 3220.28it/s]
#
# Drawing 77 posterior samples: 80it [00:00, 2067.37it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 247it [00:00, 5702.95it/s]
#
# Drawing 134 posterior samples: 211it [00:00, 3525.16it/s]
#
# Drawing 106 posterior samples: 135it [00:00, 4384.02it/s]
#
# Drawing 106 posterior samples: 187it [00:00, 4489.56it/s]
#
# Drawing 96 posterior samples: 149it [00:00, 3060.95it/s]
#
# Drawing 94 posterior samples: 165it [00:00, 3990.80it/s]
#
# Drawing 86 posterior samples: 122it [00:00, 33079.39it/s]
#
# Drawing 82 posterior samples: 131it [00:00, 7998.80it/s]
#
# Drawing 80 posterior samples: 143it [00:00, 2734.59it/s]
#
# Drawing 77 posterior samples: 86it [00:00, 2675.22it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 255it [00:00, 4389.87it/s]
#
# Drawing 134 posterior samples: 246it [00:00, 2733.68it/s]
#
# Drawing 106 posterior samples: 124it [00:00, 4449.89it/s]
#
# Drawing 106 posterior samples: 130it [00:00, 2861.98it/s]
#
# Drawing 96 posterior samples: 122it [00:00, 2452.40it/s]
#
# Drawing 94 posterior samples: 163it [00:00, 3858.47it/s]
#
# Drawing 86 posterior samples: 109it [00:00, 15746.88it/s]
#
# Drawing 82 posterior samples: 83it [00:00, 4891.28it/s]
#
# Drawing 80 posterior samples: 146it [00:00, 3108.44it/s]
#
# Drawing 77 posterior samples: 105it [00:00, 2840.92it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 247it [00:00, 5656.47it/s]
#
# Drawing 134 posterior samples: 235it [00:00, 3806.94it/s]
#
# Drawing 106 posterior samples: 148it [00:00, 5187.50it/s]
#
# Drawing 106 posterior samples: 192it [00:00, 4620.39it/s]
#
# Drawing 96 posterior samples: 142it [00:00, 2906.97it/s]
#
#
# Drawing 94 posterior samples: 164it [00:00, 462.88it/s]
#
# Drawing 86 posterior samples: 118it [00:00, 21239.72it/s]
#
# Drawing 82 posterior samples: 117it [00:00, 7140.54it/s]
#
# Drawing 80 posterior samples: 151it [00:00, 3111.75it/s]
#
# Drawing 77 posterior samples: 125it [00:00, 3878.16it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 156it [00:00, 3463.69it/s]
#
# Drawing 134 posterior samples: 194it [00:00, 2220.57it/s]
#
# Drawing 106 posterior samples:  80%|████████  | 85/106 [00:00<00:00, 2075.34it/s]
#
# Drawing 106 posterior samples: 111it [00:00, 2675.37it/s]
#
# Drawing 96 posterior samples: 158it [00:00, 3195.94it/s]
#
# Drawing 94 posterior samples: 142it [00:00, 3531.42it/s]
#
# Drawing 86 posterior samples:  49%|████▉     | 42/86 [00:00<00:00, 7774.43it/s]
#
# Drawing 82 posterior samples:  80%|████████  | 66/82 [00:00<00:00, 2691.43it/s]
#
# Drawing 80 posterior samples: 97it [00:00, 2112.37it/s]
#
# Drawing 77 posterior samples:  56%|█████▌    | 43/77 [00:00<00:00, 817.15it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 255it [00:00, 5959.68it/s]
#
# Drawing 134 posterior samples: 244it [00:00, 3438.10it/s]
#
# Drawing 106 posterior samples: 175it [00:00, 6077.24it/s]
#
# Drawing 106 posterior samples: 196it [00:00, 4691.67it/s]
#
# Drawing 96 posterior samples: 172it [00:00, 3397.08it/s]
#
# Drawing 94 posterior samples: 161it [00:00, 4031.47it/s]
#
# Drawing 86 posterior samples: 103it [00:00, 27735.83it/s]
#
# Drawing 82 posterior samples: 104it [00:00, 6274.65it/s]
#
# Drawing 80 posterior samples: 152it [00:00, 2895.09it/s]
#
# Drawing 77 posterior samples: 122it [00:00, 3869.05it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 228it [00:00, 4866.67it/s]
#
# Drawing 134 posterior samples: 185it [00:00, 3148.65it/s]
#
# Drawing 106 posterior samples: 112it [00:00, 3676.02it/s]
#
# Drawing 106 posterior samples: 167it [00:00, 3896.10it/s]
#
# Drawing 96 posterior samples: 156it [00:00, 3130.36it/s]
#
# Drawing 94 posterior samples: 141it [00:00, 3343.74it/s]
#
# Drawing 86 posterior samples: 98it [00:00, 26226.11it/s]
#
# Drawing 82 posterior samples: 96it [00:00, 5759.92it/s]
#
# Drawing 80 posterior samples: 136it [00:00, 2888.17it/s]
#
# Drawing 77 posterior samples: 94it [00:00, 2602.01it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 245it [00:00, 5520.75it/s]
#
# Drawing 134 posterior samples: 231it [00:00, 3830.69it/s]
#
# Drawing 106 posterior samples: 164it [00:00, 2355.42it/s]
#
# Drawing 106 posterior samples: 199it [00:00, 4913.16it/s]
#
# Drawing 96 posterior samples: 167it [00:00, 3331.28it/s]
#
# Drawing 94 posterior samples: 161it [00:00, 4005.07it/s]
#
# Drawing 86 posterior samples: 117it [00:00, 31729.83it/s]
#
# Drawing 82 posterior samples: 99it [00:00, 6039.53it/s]
#
# Drawing 80 posterior samples: 149it [00:00, 2076.01it/s]
#
# Drawing 77 posterior samples: 121it [00:00, 3752.17it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 158it [00:00, 3354.17it/s]
#
# Drawing 134 posterior samples: 143it [00:00, 2498.98it/s]
#
# Drawing 106 posterior samples: 127it [00:00, 2878.51it/s]
#
# Drawing 106 posterior samples: 132it [00:00, 3116.49it/s]
#
# Drawing 96 posterior samples: 154it [00:00, 3085.86it/s]
#
# Drawing 94 posterior samples: 119it [00:00, 2830.55it/s]
#
# Drawing 86 posterior samples:  26%|██▌       | 22/86 [00:00<00:00, 5844.61it/s]
#
# Drawing 82 posterior samples: 84it [00:00, 3212.36it/s]
#
# Drawing 80 posterior samples: 120it [00:00, 2618.45it/s]
#
# Drawing 77 posterior samples: 101it [00:00, 2014.20it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 260it [00:00, 6236.13it/s]
#
# Drawing 134 posterior samples: 246it [00:00, 3996.85it/s]
#
# Drawing 106 posterior samples: 169it [00:00, 5983.97it/s]
#
# Drawing 106 posterior samples: 194it [00:00, 2840.83it/s]
#
# Drawing 96 posterior samples: 164it [00:00, 1902.50it/s]
#
#
#
# Drawing 94 posterior samples: 164it [00:04, 38.49it/s]
#
#
#
# Drawing 86 posterior samples: 112it [00:00, 306.09it/s]
#
#
#
# Drawing 82 posterior samples: 112it [00:02, 50.97it/s]
#
#
# Drawing 80 posterior samples: 151it [00:00, 172.51it/s]
#
# Drawing 77 posterior samples: 126it [00:00, 3833.39it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 266it [00:00, 6020.06it/s]
#
# Drawing 134 posterior samples: 244it [00:00, 3297.69it/s]
#
# Drawing 106 posterior samples: 168it [00:00, 6107.42it/s]
#
# Drawing 106 posterior samples: 183it [00:00, 4038.78it/s]
#
# Drawing 96 posterior samples: 151it [00:00, 3161.25it/s]
#
# Drawing 94 posterior samples: 154it [00:00, 3687.05it/s]
#
# Drawing 86 posterior samples: 125it [00:00, 33324.10it/s]
#
# Drawing 82 posterior samples: 113it [00:00, 6424.00it/s]
#
# Drawing 80 posterior samples: 153it [00:00, 3215.59it/s]
#
# Drawing 77 posterior samples: 113it [00:00, 3069.96it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 206it [00:00, 4859.90it/s]
#
# Drawing 134 posterior samples: 205it [00:00, 3330.32it/s]
#
# Drawing 106 posterior samples: 121it [00:00, 4094.28it/s]
#
# Drawing 106 posterior samples: 162it [00:00, 3869.81it/s]
#
# Drawing 96 posterior samples: 181it [00:00, 3625.43it/s]
#
# Drawing 94 posterior samples: 165it [00:00, 3928.03it/s]
#
# Drawing 86 posterior samples: 103it [00:00, 1714.92it/s]
#
# Drawing 82 posterior samples: 87it [00:00, 5181.98it/s]
#
# Drawing 80 posterior samples: 134it [00:00, 2634.23it/s]
#
# Drawing 77 posterior samples: 83it [00:00, 2755.15it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 247it [00:00, 5371.46it/s]
#
# Drawing 134 posterior samples: 207it [00:00, 3633.26it/s]
#
# Drawing 106 posterior samples: 135it [00:00, 4718.67it/s]
#
# Drawing 106 posterior samples: 195it [00:00, 4755.61it/s]
#
# Drawing 96 posterior samples: 172it [00:00, 3493.65it/s]
#
# Drawing 94 posterior samples: 158it [00:00, 3813.05it/s]
#
# Drawing 86 posterior samples: 152it [00:00, 39990.85it/s]
#
# Drawing 82 posterior samples: 110it [00:00, 6039.63it/s]
#
# Drawing 80 posterior samples: 131it [00:00, 2555.28it/s]
#
# Drawing 77 posterior samples: 98it [00:00, 3043.74it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 265it [00:00, 6327.69it/s]
#
# Drawing 134 posterior samples: 239it [00:00, 3667.46it/s]
#
# Drawing 106 posterior samples: 185it [00:00, 7186.68it/s]
#
# Drawing 106 posterior samples: 200it [00:00, 4873.24it/s]
#
# Drawing 96 posterior samples: 170it [00:00, 3667.37it/s]
#
# Drawing 94 posterior samples: 175it [00:00, 4288.28it/s]
#
# Drawing 86 posterior samples: 139it [00:00, 37594.03it/s]
#
# Drawing 82 posterior samples: 129it [00:00, 7860.44it/s]
#
#
# Drawing 80 posterior samples: 146it [00:00, 261.85it/s]
#
# Drawing 77 posterior samples: 127it [00:00, 4285.93it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 268it [00:00, 6079.62it/s]
#
# Drawing 134 posterior samples: 244it [00:00, 3987.99it/s]
#
# Drawing 106 posterior samples: 178it [00:00, 6836.62it/s]
#
# Drawing 106 posterior samples: 198it [00:00, 3919.08it/s]
#
# Drawing 96 posterior samples: 181it [00:00, 3843.06it/s]
#
# Drawing 94 posterior samples: 177it [00:00, 3834.19it/s]
#
# Drawing 86 posterior samples: 149it [00:00, 40257.10it/s]
#
# Drawing 82 posterior samples: 138it [00:00, 8378.65it/s]
#
# Drawing 80 posterior samples: 153it [00:00, 3328.47it/s]
#
# Drawing 77 posterior samples: 136it [00:00, 3661.64it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 153it [00:00, 2275.83it/s]
#
# Drawing 134 posterior samples:  91%|█████████ | 122/134 [00:00<00:00, 1400.27it/s]
#
# Drawing 106 posterior samples:   3%|▎         | 3/106 [00:00<00:00, 226.58it/s]
#
# Drawing 106 posterior samples: 107it [00:00, 2620.97it/s]
#
# Drawing 96 posterior samples: 119it [00:00, 2472.76it/s]
#
# Drawing 94 posterior samples: 125it [00:00, 1959.23it/s]
#
# Drawing 86 posterior samples:   1%|          | 1/86 [00:00<00:00, 500.93it/s]
#
# Drawing 82 posterior samples:  10%|▉         | 8/82 [00:00<00:00, 958.51it/s]
#
# Drawing 80 posterior samples: 86it [00:00, 1119.79it/s]
#
# Drawing 77 posterior samples:  34%|███▍      | 26/77 [00:00<00:00, 874.49it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 164it [00:00, 3799.44it/s]
#
# Drawing 134 posterior samples: 173it [00:00, 2888.17it/s]
#
# Drawing 106 posterior samples:  97%|█████████▋| 103/106 [00:00<00:00, 2540.00it/s]
#
# Drawing 106 posterior samples: 158it [00:00, 3745.17it/s]
#
# Drawing 96 posterior samples: 156it [00:00, 3117.94it/s]
#
# Drawing 94 posterior samples: 96it [00:00, 2435.54it/s]
#
# Drawing 86 posterior samples:  16%|█▋        | 14/86 [00:00<00:00, 3755.69it/s]
#
# Drawing 82 posterior samples: 95it [00:00, 2739.87it/s]
#
# Drawing 80 posterior samples: 107it [00:00, 2155.53it/s]
#
# Drawing 77 posterior samples: 111it [00:00, 2476.56it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 218it [00:00, 4939.91it/s]
#
# Drawing 134 posterior samples: 196it [00:00, 3226.70it/s]
#
# Drawing 106 posterior samples: 135it [00:00, 5116.81it/s]
#
# Drawing 106 posterior samples: 152it [00:00, 3555.61it/s]
#
# Drawing 96 posterior samples: 164it [00:00, 3414.88it/s]
#
# Drawing 94 posterior samples: 150it [00:00, 3688.38it/s]
#
# Drawing 86 posterior samples: 89it [00:00, 24230.37it/s]
#
# Drawing 82 posterior samples: 89it [00:00, 5470.38it/s]
#
# Drawing 80 posterior samples: 133it [00:00, 2677.60it/s]
#
# Drawing 77 posterior samples: 105it [00:00, 3567.60it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 251it [00:00, 5993.67it/s]
#
# Drawing 134 posterior samples: 235it [00:00, 3401.77it/s]
#
# Drawing 106 posterior samples: 160it [00:00, 6018.46it/s]
#
# Drawing 106 posterior samples: 187it [00:00, 4463.68it/s]
#
# Drawing 96 posterior samples: 179it [00:00, 3691.88it/s]
#
# Drawing 94 posterior samples: 168it [00:00, 4296.71it/s]
#
# Drawing 86 posterior samples: 107it [00:00, 21731.09it/s]
#
# Drawing 82 posterior samples: 121it [00:00, 6602.63it/s]
#
# Drawing 80 posterior samples: 144it [00:00, 2962.08it/s]
#
# Drawing 77 posterior samples: 107it [00:00, 3446.06it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 269it [00:00, 6524.53it/s]
#
# Drawing 134 posterior samples: 236it [00:00, 3850.17it/s]
#
# Drawing 106 posterior samples: 186it [00:00, 7013.07it/s]
#
# Drawing 106 posterior samples: 195it [00:00, 4912.22it/s]
#
# Drawing 96 posterior samples: 167it [00:00, 3296.12it/s]
#
# Drawing 94 posterior samples: 165it [00:00, 3954.31it/s]
#
# Drawing 86 posterior samples: 117it [00:00, 18633.57it/s]
#
# Drawing 82 posterior samples: 125it [00:00, 7687.17it/s]
#
# Drawing 80 posterior samples: 155it [00:00, 3365.95it/s]
#
# Drawing 77 posterior samples: 111it [00:00, 3272.01it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 221it [00:00, 5136.57it/s]
#
# Drawing 134 posterior samples: 201it [00:00, 3390.61it/s]
#
# Drawing 106 posterior samples: 150it [00:00, 5604.76it/s]
#
# Drawing 106 posterior samples: 122it [00:00, 2876.35it/s]
#
# Drawing 96 posterior samples: 104it [00:00, 2170.50it/s]
#
# Drawing 94 posterior samples: 154it [00:00, 3819.43it/s]
#
# Drawing 86 posterior samples: 108it [00:00, 29132.73it/s]
#
# Drawing 82 posterior samples: 111it [00:00, 6790.07it/s]
#
# Drawing 80 posterior samples: 120it [00:00, 2281.96it/s]
#
# Drawing 77 posterior samples: 100it [00:00, 1709.30it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 259it [00:00, 5925.97it/s]
#
# Drawing 134 posterior samples: 233it [00:00, 3767.09it/s]
#
# Drawing 106 posterior samples: 151it [00:00, 5701.71it/s]
#
# Drawing 106 posterior samples: 169it [00:00, 4179.79it/s]
#
# Drawing 96 posterior samples: 158it [00:00, 3128.56it/s]
#
# Drawing 94 posterior samples: 137it [00:00, 3293.61it/s]
#
# Drawing 86 posterior samples: 112it [00:00, 20667.96it/s]
#
# Drawing 82 posterior samples: 92it [00:00, 5634.30it/s]
#
# Drawing 80 posterior samples: 138it [00:00, 2993.00it/s]
#
# Drawing 77 posterior samples: 96it [00:00, 2925.41it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 193it [00:00, 4408.42it/s]
#
# Drawing 134 posterior samples: 188it [00:00, 3169.84it/s]
#
# Drawing 106 posterior samples: 140it [00:00, 3391.08it/s]
#
# Drawing 106 posterior samples: 153it [00:00, 3730.31it/s]
#
# Drawing 96 posterior samples: 143it [00:00, 2952.75it/s]
#
# Drawing 94 posterior samples: 104it [00:00, 1791.52it/s]
#
# Drawing 86 posterior samples: 94it [00:00, 17093.63it/s]
#
# Drawing 82 posterior samples: 107it [00:00, 5934.89it/s]
#
# Drawing 80 posterior samples: 121it [00:00, 2401.45it/s]
#
# Drawing 77 posterior samples: 116it [00:00, 2536.98it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 256it [00:00, 4974.97it/s]
#
# Drawing 134 posterior samples: 256it [00:00, 4453.42it/s]
#
# Drawing 106 posterior samples: 177it [00:00, 6361.65it/s]
#
# Drawing 106 posterior samples: 200it [00:00, 4862.20it/s]
#
# Drawing 96 posterior samples: 174it [00:00, 3519.75it/s]
#
# Drawing 94 posterior samples: 162it [00:00, 3956.82it/s]
#
# Drawing 86 posterior samples: 121it [00:00, 32643.65it/s]
#
# Drawing 82 posterior samples: 114it [00:00, 4674.69it/s]
#
# Drawing 80 posterior samples: 146it [00:00, 2918.54it/s]
#
# Drawing 77 posterior samples: 126it [00:00, 4256.94it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 257it [00:00, 6048.68it/s]
#
# Drawing 134 posterior samples: 245it [00:00, 4201.42it/s]
#
# Drawing 106 posterior samples: 165it [00:00, 6014.67it/s]
#
# Drawing 106 posterior samples: 183it [00:00, 4692.02it/s]
#
# Drawing 96 posterior samples: 153it [00:00, 2940.98it/s]
#
# Drawing 94 posterior samples: 155it [00:00, 3918.63it/s]
#
# Drawing 86 posterior samples: 128it [00:00, 34578.83it/s]
#
# Drawing 82 posterior samples: 111it [00:00, 6797.60it/s]
#
# Drawing 80 posterior samples: 140it [00:00, 2712.41it/s]
#
# Drawing 77 posterior samples: 106it [00:00, 3274.02it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 253it [00:00, 5970.22it/s]
#
# Drawing 134 posterior samples: 251it [00:00, 3836.53it/s]
#
# Drawing 106 posterior samples: 177it [00:00, 6729.74it/s]
#
# Drawing 106 posterior samples: 204it [00:00, 4774.82it/s]
#
# Drawing 96 posterior samples: 180it [00:00, 3575.15it/s]
#
# Drawing 94 posterior samples: 169it [00:00, 3751.93it/s]
#
# Drawing 86 posterior samples: 121it [00:00, 32321.41it/s]
#
# Drawing 82 posterior samples: 107it [00:00, 5637.86it/s]
#
# Drawing 80 posterior samples: 153it [00:00, 2954.29it/s]
#
# Drawing 77 posterior samples: 129it [00:00, 3922.30it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 252it [00:00, 5959.13it/s]
#
# Drawing 134 posterior samples: 239it [00:00, 2960.79it/s]
#
# Drawing 106 posterior samples: 166it [00:00, 6125.55it/s]
#
# Drawing 106 posterior samples: 189it [00:00, 4462.15it/s]
#
# Drawing 96 posterior samples: 181it [00:00, 3605.72it/s]
#
# Drawing 94 posterior samples: 171it [00:00, 2432.50it/s]
#
# Drawing 86 posterior samples: 110it [00:00, 28783.67it/s]
#
# Drawing 82 posterior samples: 109it [00:00, 6563.86it/s]
#
# Drawing 80 posterior samples: 148it [00:00, 2850.06it/s]
#
# Drawing 77 posterior samples: 124it [00:00, 3950.64it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 281it [00:00, 6215.82it/s]
#
# Drawing 134 posterior samples: 249it [00:00, 4231.54it/s]
#
# Drawing 106 posterior samples: 178it [00:00, 5944.44it/s]
#
# Drawing 106 posterior samples: 193it [00:00, 4489.72it/s]
#
# Drawing 96 posterior samples: 177it [00:00, 3520.53it/s]
#
# Drawing 94 posterior samples: 171it [00:00, 4086.76it/s]
#
# Drawing 86 posterior samples: 118it [00:00, 27300.34it/s]
#
# Drawing 82 posterior samples: 135it [00:00, 8048.20it/s]
#
# Drawing 80 posterior samples: 140it [00:00, 2987.59it/s]
#
# Drawing 77 posterior samples: 125it [00:00, 3205.09it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 272it [00:00, 6034.91it/s]
#
# Drawing 134 posterior samples: 253it [00:00, 4127.79it/s]
#
# Drawing 106 posterior samples: 174it [00:00, 5966.15it/s]
#
# Drawing 106 posterior samples: 198it [00:00, 4615.89it/s]
#
# Drawing 96 posterior samples: 180it [00:00, 3579.08it/s]
#
# Drawing 94 posterior samples: 179it [00:00, 4227.03it/s]
#
# Drawing 86 posterior samples: 144it [00:00, 38828.66it/s]
#
# Drawing 82 posterior samples: 133it [00:00, 7011.42it/s]
#
# Drawing 80 posterior samples: 141it [00:00, 2824.47it/s]
#
# Drawing 77 posterior samples: 120it [00:00, 3595.12it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 167it [00:00, 3808.11it/s]
#
# Drawing 134 posterior samples: 139it [00:00, 1509.70it/s]
#
# Drawing 106 posterior samples:  32%|███▏      | 34/106 [00:00<00:00, 1191.77it/s]
#
# Drawing 106 posterior samples: 108it [00:00, 2507.51it/s]
#
# Drawing 96 posterior samples: 122it [00:00, 2492.05it/s]
#
# Drawing 94 posterior samples: 128it [00:00, 3037.30it/s]
#
# Drawing 86 posterior samples:   1%|          | 1/86 [00:00<00:00, 239.44it/s]
#
# Drawing 82 posterior samples:  10%|▉         | 8/82 [00:00<00:00, 943.15it/s]
#
# Drawing 80 posterior samples: 82it [00:00, 1765.66it/s]
#
# Drawing 77 posterior samples:  82%|████████▏ | 63/77 [00:00<00:00, 975.68it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 184it [00:00, 2842.03it/s]
#
#
# Drawing 134 posterior samples: 170it [00:00, 1333.73it/s]
#
# Drawing 106 posterior samples:  28%|██▊       | 30/106 [00:00<00:00, 1025.30it/s]
#
# Drawing 106 posterior samples: 163it [00:00, 3622.14it/s]
#
# Drawing 96 posterior samples: 125it [00:00, 1724.41it/s]
#
# Drawing 94 posterior samples: 121it [00:00, 2837.44it/s]
#
# Drawing 86 posterior samples: 106it [00:00, 11115.18it/s]
#
# Drawing 82 posterior samples: 99it [00:00, 6003.99it/s]
#
# Drawing 80 posterior samples: 122it [00:00, 2602.11it/s]
#
# Drawing 77 posterior samples: 91it [00:00, 1575.00it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 247it [00:00, 5740.72it/s]
#
# Drawing 134 posterior samples: 236it [00:00, 3634.46it/s]
#
# Drawing 106 posterior samples: 171it [00:00, 6020.63it/s]
#
# Drawing 106 posterior samples: 199it [00:00, 4957.57it/s]
#
# Drawing 96 posterior samples: 175it [00:00, 3451.89it/s]
#
# Drawing 94 posterior samples: 160it [00:00, 3819.45it/s]
#
# Drawing 86 posterior samples: 127it [00:00, 27598.39it/s]
#
# Drawing 82 posterior samples: 100it [00:00, 6059.56it/s]
#
# Drawing 80 posterior samples: 146it [00:00, 3155.82it/s]
#
# Drawing 77 posterior samples: 131it [00:00, 3436.90it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 272it [00:00, 5964.48it/s]
#
# Drawing 134 posterior samples: 249it [00:00, 4149.11it/s]
#
# Drawing 106 posterior samples: 184it [00:00, 6010.62it/s]
#
# Drawing 106 posterior samples: 201it [00:00, 4631.03it/s]
#
# Drawing 96 posterior samples: 171it [00:00, 3431.10it/s]
#
# Drawing 94 posterior samples: 167it [00:00, 3959.84it/s]
#
# Drawing 86 posterior samples: 129it [00:00, 25676.97it/s]
#
# Drawing 82 posterior samples: 139it [00:00, 8331.19it/s]
#
# Drawing 80 posterior samples: 143it [00:00, 3073.46it/s]
#
# Drawing 77 posterior samples: 124it [00:00, 3278.33it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 264it [00:00, 5693.60it/s]
#
# Drawing 134 posterior samples: 226it [00:00, 3491.94it/s]
#
# Drawing 106 posterior samples: 167it [00:00, 3928.09it/s]
#
# Drawing 106 posterior samples: 193it [00:00, 4408.18it/s]
#
# Drawing 96 posterior samples: 175it [00:00, 2596.99it/s]
#
# Drawing 94 posterior samples: 171it [00:00, 4296.10it/s]
#
# Drawing 86 posterior samples: 127it [00:00, 28500.62it/s]
#
# Drawing 82 posterior samples: 122it [00:00, 6376.47it/s]
#
# Drawing 80 posterior samples: 144it [00:00, 2838.14it/s]
#
# Drawing 77 posterior samples: 79it [00:00, 934.20it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 244it [00:00, 5255.86it/s]
#
# Drawing 134 posterior samples: 213it [00:00, 3492.75it/s]
#
# Drawing 106 posterior samples: 163it [00:00, 5204.72it/s]
#
# Drawing 106 posterior samples: 182it [00:00, 4247.89it/s]
#
# Drawing 96 posterior samples: 172it [00:00, 3106.22it/s]
#
# Drawing 94 posterior samples: 169it [00:00, 4287.54it/s]
#
# Drawing 86 posterior samples: 127it [00:00, 23410.24it/s]
#
# Drawing 82 posterior samples: 98it [00:00, 5939.40it/s]
#
# Drawing 80 posterior samples: 153it [00:00, 2495.60it/s]
#
# Drawing 77 posterior samples: 117it [00:00, 3652.60it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 174it [00:00, 3427.65it/s]
#
# Drawing 134 posterior samples: 159it [00:00, 2743.48it/s]
#
# Drawing 106 posterior samples:   6%|▌         | 6/106 [00:00<00:00, 364.09it/s]
#
# Drawing 106 posterior samples: 153it [00:00, 3598.30it/s]
#
# Drawing 96 posterior samples: 146it [00:00, 2918.04it/s]
#
# Drawing 94 posterior samples: 138it [00:00, 2329.20it/s]
#
# Drawing 86 posterior samples:   3%|▎         | 3/86 [00:00<00:00, 1499.04it/s]
#
# Drawing 82 posterior samples: 103it [00:00, 5415.53it/s]
#
# Drawing 80 posterior samples: 142it [00:00, 2827.29it/s]
#
# Drawing 77 posterior samples: 86it [00:00, 2533.90it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 259it [00:00, 6160.33it/s]
#
# Drawing 134 posterior samples: 215it [00:00, 3257.44it/s]
#
# Drawing 106 posterior samples: 153it [00:00, 5416.98it/s]
#
# Drawing 106 posterior samples: 174it [00:00, 4077.60it/s]
#
# Drawing 96 posterior samples: 165it [00:00, 3340.40it/s]
#
# Drawing 94 posterior samples: 163it [00:00, 3890.16it/s]
#
# Drawing 86 posterior samples: 118it [00:00, 19482.28it/s]
#
# Drawing 82 posterior samples: 128it [00:00, 7773.87it/s]
#
# Drawing 80 posterior samples: 120it [00:00, 2599.13it/s]
#
# Drawing 77 posterior samples: 112it [00:00, 1977.00it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 249it [00:00, 5105.88it/s]
#
# Drawing 134 posterior samples: 216it [00:00, 3525.96it/s]
#
# Drawing 106 posterior samples: 156it [00:00, 4017.98it/s]
#
# Drawing 106 posterior samples: 171it [00:00, 3283.58it/s]
#
# Drawing 96 posterior samples: 174it [00:00, 3758.86it/s]
#
# Drawing 94 posterior samples:  82%|████████▏ | 77/94 [00:00<00:00, 1187.02it/s]
#
# Drawing 86 posterior samples: 88it [00:00, 16163.02it/s]
#
# Drawing 82 posterior samples: 90it [00:00, 5506.66it/s]
#
# Drawing 80 posterior samples: 142it [00:00, 2741.14it/s]
#
# Drawing 77 posterior samples:  78%|███████▊  | 60/77 [00:00<00:00, 1361.32it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 246it [00:00, 5042.31it/s]
#
# Drawing 134 posterior samples: 222it [00:00, 3900.26it/s]
#
# Drawing 106 posterior samples: 166it [00:00, 5575.92it/s]
#
# Drawing 106 posterior samples: 177it [00:00, 3877.12it/s]
#
# Drawing 96 posterior samples: 148it [00:00, 3204.60it/s]
#
# Drawing 94 posterior samples: 152it [00:00, 3705.67it/s]
#
# Drawing 86 posterior samples: 90it [00:00, 24811.84it/s]
#
# ...
#
# Drawing 145 posterior samples: 225it [00:00, 5352.73it/s]
#
# Drawing 134 posterior samples: 197it [00:00, 3400.54it/s]
#
# Drawing 106 posterior samples: 151it [00:00, 5316.64it/s]
#
# Drawing 106 posterior samples: 156it [00:00, 3870.45it/s]
#
# Drawing 96 posterior samples: 174it [00:00, 3673.99it/s]
#
# Drawing 94 posterior samples: 135it [00:00, 3357.79it/s]
#
# Drawing 86 posterior samples: 89it [00:00, 16299.58it/s]
#
#
# Drawing 82 posterior samples: 113it [00:00, 651.78it/s]
#
# Drawing 80 posterior samples: 129it [00:00, 2772.83it/s]
#
# Drawing 77 posterior samples: 89it [00:00, 2795.89it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 261it [00:00, 4747.34it/s]
#
#
# Drawing 134 posterior samples: 244it [00:00, 2374.03it/s]
#
# Drawing 106 posterior samples: 172it [00:00, 6109.43it/s]
#
# Drawing 106 posterior samples: 202it [00:00, 2865.90it/s]
#
# Drawing 96 posterior samples: 173it [00:00, 3719.57it/s]
#
# Drawing 94 posterior samples: 173it [00:00, 3394.93it/s]
#
# Drawing 86 posterior samples: 139it [00:00, 22020.25it/s]
#
# Drawing 82 posterior samples: 128it [00:00, 7290.97it/s]
#
# Drawing 80 posterior samples: 145it [00:00, 2424.34it/s]
#
# Drawing 77 posterior samples: 117it [00:00, 3053.12it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 155it [00:00, 3069.05it/s]
#
# Drawing 134 posterior samples: 187it [00:00, 2814.25it/s]
#
# Drawing 106 posterior samples:  95%|█████████▌| 101/106 [00:00<00:00, 2224.25it/s]
#
# Drawing 106 posterior samples: 169it [00:00, 3664.23it/s]
#
# Drawing 96 posterior samples: 123it [00:00, 2338.84it/s]
#
# Drawing 94 posterior samples: 131it [00:00, 2645.00it/s]
#
# Drawing 86 posterior samples:  90%|████████▉ | 77/86 [00:00<00:00, 7518.07it/s]
#
# Drawing 82 posterior samples: 104it [00:00, 6329.74it/s]
#
# Drawing 80 posterior samples: 152it [00:00, 3306.22it/s]
#
# Drawing 77 posterior samples: 91it [00:00, 2449.06it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 263it [00:00, 4304.84it/s]
#
# Drawing 134 posterior samples: 242it [00:00, 3635.57it/s]
#
# Drawing 106 posterior samples: 172it [00:00, 5288.54it/s]
#
# Drawing 106 posterior samples: 200it [00:00, 4987.43it/s]
#
# Drawing 96 posterior samples: 171it [00:00, 2489.12it/s]
#
# Drawing 94 posterior samples: 164it [00:00, 4226.28it/s]
#
# Drawing 86 posterior samples: 117it [00:00, 30594.36it/s]
#
# Drawing 82 posterior samples: 107it [00:00, 6495.93it/s]
#
#
# Drawing 80 posterior samples: 144it [00:00, 1092.69it/s]
#
# Drawing 77 posterior samples: 130it [00:00, 4015.49it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 211it [00:00, 2329.21it/s]
#
# Drawing 134 posterior samples: 191it [00:00, 3296.32it/s]
#
# Drawing 106 posterior samples:  57%|█████▋    | 60/106 [00:00<00:00, 1118.60it/s]
#
# Drawing 106 posterior samples: 112it [00:00, 1687.80it/s]
#
# Drawing 96 posterior samples: 134it [00:00, 2046.78it/s]
#
# Drawing 94 posterior samples: 124it [00:00, 2112.11it/s]
#
# Drawing 86 posterior samples: 95it [00:00, 16863.13it/s]
#
# Drawing 82 posterior samples: 112it [00:00, 4725.41it/s]
#
# Drawing 80 posterior samples: 102it [00:00, 1742.13it/s]
#
# Drawing 77 posterior samples: 98it [00:00, 2383.47it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 268it [00:00, 5680.98it/s]
#
# Drawing 134 posterior samples: 253it [00:00, 3668.82it/s]
#
# Drawing 106 posterior samples: 176it [00:00, 5133.68it/s]
#
# Drawing 106 posterior samples: 197it [00:00, 4316.44it/s]
#
# Drawing 96 posterior samples: 175it [00:00, 3331.20it/s]
#
# Drawing 94 posterior samples: 165it [00:00, 3862.83it/s]
#
# Drawing 86 posterior samples: 129it [00:00, 34502.31it/s]
#
# Drawing 82 posterior samples: 134it [00:00, 8130.50it/s]
#
# Drawing 80 posterior samples: 147it [00:00, 3165.59it/s]
#
# Drawing 77 posterior samples: 129it [00:00, 2133.02it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 268it [00:00, 2703.42it/s]
#
#
# Drawing 134 posterior samples: 246it [00:00, 2008.61it/s]
#
# Drawing 106 posterior samples: 185it [00:00, 6292.70it/s]
#
#
# Drawing 106 posterior samples: 191it [00:00, 775.03it/s]
#
# Drawing 96 posterior samples: 164it [00:00, 3462.82it/s]
#
# Drawing 94 posterior samples: 175it [00:00, 4365.14it/s]
#
# Drawing 86 posterior samples: 124it [00:00, 33137.54it/s]
#
# Drawing 82 posterior samples: 132it [00:00, 4633.78it/s]
#
# Drawing 80 posterior samples: 146it [00:00, 1958.62it/s]
#
# Drawing 77 posterior samples: 127it [00:00, 4112.19it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 225it [00:00, 4580.93it/s]
#
#
# Drawing 134 posterior samples: 206it [00:00, 1024.21it/s]
#
# Drawing 106 posterior samples: 148it [00:00, 4786.73it/s]
#
# Drawing 106 posterior samples: 185it [00:00, 4050.90it/s]
#
# Drawing 96 posterior samples: 165it [00:00, 3169.30it/s]
#
# Drawing 94 posterior samples: 146it [00:00, 2966.97it/s]
#
# Drawing 86 posterior samples: 89it [00:00, 5388.49it/s]
#
# Drawing 82 posterior samples: 84it [00:00, 5082.32it/s]
#
# Drawing 80 posterior samples: 144it [00:00, 2827.77it/s]
#
# Drawing 77 posterior samples: 109it [00:00, 3443.65it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 260it [00:00, 3247.63it/s]
#
# Drawing 134 posterior samples: 245it [00:00, 4184.28it/s]
#
# Drawing 106 posterior samples: 174it [00:00, 5034.90it/s]
#
# Drawing 106 posterior samples: 198it [00:00, 4283.48it/s]
#
# Drawing 96 posterior samples: 173it [00:00, 3276.64it/s]
#
# Drawing 94 posterior samples: 173it [00:00, 3541.92it/s]
#
# Drawing 86 posterior samples: 117it [00:00, 12427.10it/s]
#
# Drawing 82 posterior samples: 114it [00:00, 6926.51it/s]
#
# Drawing 80 posterior samples: 141it [00:00, 3035.25it/s]
#
# Drawing 77 posterior samples: 112it [00:00, 2020.49it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 249it [00:00, 5161.49it/s]
#
# Drawing 134 posterior samples: 220it [00:00, 2862.24it/s]
#
# Drawing 106 posterior samples: 148it [00:00, 5308.75it/s]
#
# Drawing 106 posterior samples: 176it [00:00, 4426.44it/s]
#
# Drawing 96 posterior samples: 163it [00:00, 2469.65it/s]
#
# Drawing 94 posterior samples: 160it [00:00, 4111.81it/s]
#
# Drawing 86 posterior samples: 99it [00:00, 18123.87it/s]
#
# Drawing 82 posterior samples: 112it [00:00, 4525.65it/s]
#
# Drawing 80 posterior samples: 150it [00:00, 3258.91it/s]
#
# Drawing 77 posterior samples: 105it [00:00, 3369.72it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 244it [00:00, 5708.64it/s]
#
# Drawing 134 posterior samples: 225it [00:00, 2388.11it/s]
#
# Drawing 106 posterior samples: 156it [00:00, 5574.40it/s]
#
# Drawing 106 posterior samples: 171it [00:00, 2498.92it/s]
#
# Drawing 96 posterior samples: 168it [00:00, 3605.38it/s]
#
# Drawing 94 posterior samples: 159it [00:00, 4013.33it/s]
#
# Drawing 86 posterior samples: 98it [00:00, 25872.84it/s]
#
# Drawing 82 posterior samples: 96it [00:00, 5723.08it/s]
#
# Drawing 80 posterior samples: 150it [00:00, 3239.98it/s]
#
# Drawing 77 posterior samples: 123it [00:00, 3906.38it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 217it [00:00, 4995.30it/s]
#
# Drawing 134 posterior samples: 185it [00:00, 2227.07it/s]
#
# Drawing 106 posterior samples: 116it [00:00, 2747.92it/s]
#
# Drawing 106 posterior samples: 164it [00:00, 2663.99it/s]
#
# Drawing 96 posterior samples: 169it [00:00, 3578.88it/s]
#
# Drawing 94 posterior samples: 152it [00:00, 2718.66it/s]
#
# Drawing 86 posterior samples: 87it [00:00, 15856.45it/s]
#
# Drawing 82 posterior samples: 95it [00:00, 5747.53it/s]
#
# Drawing 80 posterior samples: 138it [00:00, 2997.98it/s]
#
# Drawing 77 posterior samples: 90it [00:00, 2947.83it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 240it [00:00, 3755.78it/s]
#
# Drawing 134 posterior samples: 230it [00:00, 3946.26it/s]
#
# Drawing 106 posterior samples: 165it [00:00, 5860.45it/s]
#
# Drawing 106 posterior samples: 195it [00:00, 4852.07it/s]
#
# Drawing 96 posterior samples: 158it [00:00, 3381.76it/s]
#
# Drawing 94 posterior samples: 153it [00:00, 1706.57it/s]
#
# Drawing 86 posterior samples: 105it [00:00, 28149.69it/s]
#
# Drawing 82 posterior samples: 95it [00:00, 5695.36it/s]
#
# Drawing 80 posterior samples: 153it [00:00, 1583.46it/s]
#
# Drawing 77 posterior samples: 121it [00:00, 3797.62it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples:  32%|███▏      | 47/145 [00:00<00:00, 763.72it/s]
#
# Drawing 134 posterior samples:  25%|██▌       | 34/134 [00:00<00:00, 598.32it/s]
#
# Drawing 106 posterior samples:   0%|          | 0/106 [00:00<?, ?it/s]
#
# Drawing 106 posterior samples:  63%|██████▎   | 67/106 [00:00<00:00, 1016.22it/s]
#
# Drawing 96 posterior samples: 98it [00:00, 1452.84it/s]
#
# Drawing 94 posterior samples: 127it [00:00, 2188.79it/s]
#
# Drawing 86 posterior samples:   0%|          | 0/86 [00:00<?, ?it/s]
#
# Drawing 82 posterior samples:  10%|▉         | 8/82 [00:00<00:00, 500.10it/s]
#
# Drawing 80 posterior samples:  35%|███▌      | 28/80 [00:00<00:00, 619.11it/s]
#
# Drawing 77 posterior samples:   0%|          | 0/77 [00:00<?, ?it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 177it [00:00, 3272.51it/s]
#
#
# Drawing 134 posterior samples: 158it [00:00, 1550.08it/s]
#
# Drawing 106 posterior samples:  92%|█████████▏| 97/106 [00:00<00:00, 2424.44it/s]
#
# Drawing 106 posterior samples: 163it [00:00, 3273.60it/s]
#
# Drawing 96 posterior samples: 157it [00:00, 2601.98it/s]
#
# Drawing 94 posterior samples: 135it [00:00, 3534.08it/s]
#
# Drawing 86 posterior samples: 92it [00:00, 16829.17it/s]
#
# Drawing 82 posterior samples: 127it [00:00, 6253.76it/s]
#
# Drawing 80 posterior samples: 124it [00:00, 2348.21it/s]
#
# Drawing 77 posterior samples:  47%|████▋     | 36/77 [00:00<00:00, 942.05it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 249it [00:00, 6055.44it/s]
#
# Drawing 134 posterior samples: 238it [00:00, 3267.88it/s]
#
# Drawing 106 posterior samples: 178it [00:00, 5377.43it/s]
#
# Drawing 106 posterior samples: 191it [00:00, 3963.19it/s]
#
# Drawing 96 posterior samples: 173it [00:00, 3254.69it/s]
#
# Drawing 94 posterior samples: 166it [00:00, 3473.16it/s]
#
# Drawing 86 posterior samples: 127it [00:00, 12147.42it/s]
#
# Drawing 82 posterior samples: 106it [00:00, 6525.51it/s]
#
# Drawing 80 posterior samples: 150it [00:00, 2843.80it/s]
#
# Drawing 77 posterior samples: 113it [00:00, 2718.26it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 270it [00:00, 5470.51it/s]
#
# Drawing 134 posterior samples: 243it [00:00, 3107.57it/s]
#
# Drawing 106 posterior samples: 174it [00:00, 6508.77it/s]
#
# Drawing 106 posterior samples: 199it [00:00, 4283.44it/s]
#
# Drawing 96 posterior samples: 178it [00:00, 2968.23it/s]
#
# Drawing 94 posterior samples: 177it [00:00, 4576.59it/s]
#
# Drawing 86 posterior samples: 120it [00:00, 32810.72it/s]
#
# Drawing 82 posterior samples: 132it [00:00, 8074.67it/s]
#
# Drawing 80 posterior samples: 143it [00:00, 2691.56it/s]
#
# Drawing 77 posterior samples: 137it [00:00, 2703.94it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 235it [00:00, 4600.00it/s]
#
# Drawing 134 posterior samples: 217it [00:00, 2933.99it/s]
#
# Drawing 106 posterior samples: 161it [00:00, 6015.24it/s]
#
# Drawing 106 posterior samples: 185it [00:00, 4671.98it/s]
#
# Drawing 96 posterior samples: 179it [00:00, 2746.97it/s]
#
# Drawing 94 posterior samples: 168it [00:00, 4316.90it/s]
#
# Drawing 86 posterior samples: 109it [00:00, 29770.08it/s]
#
# Drawing 82 posterior samples: 89it [00:00, 5369.89it/s]
#
# Drawing 80 posterior samples: 123it [00:00, 2334.54it/s]
#
# Drawing 77 posterior samples: 114it [00:00, 2274.88it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 264it [00:00, 5543.08it/s]
#
# Drawing 134 posterior samples: 248it [00:00, 3479.85it/s]
#
# Drawing 106 posterior samples: 157it [00:00, 5897.00it/s]
#
# Drawing 106 posterior samples: 197it [00:00, 4184.17it/s]
#
# Drawing 96 posterior samples: 177it [00:00, 3356.08it/s]
#
# Drawing 94 posterior samples: 179it [00:00, 4174.41it/s]
#
# Drawing 86 posterior samples: 102it [00:00, 27712.07it/s]
#
# Drawing 82 posterior samples: 121it [00:00, 4550.36it/s]
#
# Drawing 80 posterior samples: 152it [00:00, 2591.97it/s]
#
# Drawing 77 posterior samples: 113it [00:00, 3714.60it/s]
# INFO:root:Sampling models with [145, 134, 106, 106, 96, 94, 86, 82, 80, 77] samples each.
#
# Drawing 145 posterior samples: 263it [00:00, 6188.86it/s]
#
# Drawing 134 posterior samples: 244it [00:00, 4244.60it/s]
#
# Drawing 106 posterior samples: 181it [00:00, 6838.56it/s]
#
# Drawing 106 posterior samples: 204it [00:00, 5097.39it/s]
#
# Drawing 96 posterior samples: 170it [00:00, 3674.85it/s]
#
# Drawing 94 posterior samples: 168it [00:00, 4304.64it/s]
#
# Drawing 86 posterior samples: 132it [00:00, 35756.14it/s]
#
# Drawing 82 posterior samples: 138it [00:00, 8453.54it/s]
#
# Drawing 80 posterior samples: 150it [00:00, 3245.71it/s]
#
# Drawing 77 posterior samples: 101it [00:00, 3363.78it/s]
# 100%|██████████| 200/200 [01:49<00:00,  1.83it/s]

# %%
samps = np.array(samps)
trues = np.array(yobs)
trues.shape, samps.shape
# Out:
# ((200, 5), (200, 1000, 5))

# %%
Nparams = trues.shape[-1]

f, axs = plt.subplots(1, Nparams, figsize=(5*Nparams, 4), gridspec_kw=dict(wspace=0.3))
for i in range(Nparams):
    means = np.average(samps[:, :, i], axis=1)
    stds = np.sqrt(np.average((samps[:, :, i] - means[:, None])**2, axis=1))
    axs[i].plot(yrange[i], yrange[i], 'r--')
    axs[i].plot(trues[:, i], means, 'k.')
    axs[i].errorbar(trues[:, i], means, yerr=stds, fmt='none', ecolor='k', elinewidth=1)
    axs[i].set(xlabel=f'True {names[i]}', ylabel=f'Predicted {names[i]}')

# %% [markdown]
# ## Predict across many

# %%
summaries = ['Pk0', 'Pk2']
tracer = 'halo'

# %%
# Load an observed summary
nbody = 'mtnglike'
sim = 'fastpm'
L, N = 3000, 384
lhid = 663
# summaries = ['Pk0', 'Pk2']

simpath = join(wdir, nbody, sim, f'L{L}-N{N}', f'{lhid}', 'diag')

summ = {}
with h5py.File(join(simpath, 'ngc_lightcone/hod06633_aug00000.h5'), 'r') as f:
    k = f['Pk_k3D'][:]
    for s in ['Pk0', 'Pk2', 'Pk4']:
        if s[:2] != 'Pk':
            raise NotImplementedError
        Pk = f['Pk'][:, int(s[-1])//2]  # get the pole
        summ[s] = [{'k': k, 'value': Pk}]
# a=f'{2/3:.6f}'
# with h5py.File(join(simpath, 'galaxies/hod20003.h5'), 'r') as f:
#     k = f[a]['Pk_k3D'][:]
#     for s in ['Pk0', 'Pk2', 'Pk4']:
#         if s[:2] != 'Pk':
#             raise NotImplementedError
#         Pk = f[a]['Pk'][:, int(s[-1])//2]  # get the pole
#         summ[s] = [{'k': k, 'value': Pk}]

#     truecosmo = f.attrs['cosmo_params']
#     truehod = f.attrs['HOD_params']
#     trueparams = np.concatenate([truecosmo, truehod])
# with h5py.File(join(simpath, 'halos.h5'), 'r') as f:
#     k = f[a]['Pk_k3D'][:]
#     for s in ['Pk0', 'Pk2', 'Pk4']:
#         if s[:2] != 'Pk':
#             raise NotImplementedError
#         Pk = f[a]['Pk'][:, int(s[-1])//2]  # get the pole
#         summ[s] = [{'k': k, 'value': Pk}]

#     truecosmo = f.attrs['cosmo_params']
#     # truehod = f.attrs['HOD_params']
#     trueparams = truecosmo # np.concatenate([truecosmo, truehod])

# truecosmo = [0.3175, 0.04900, 0.6711, 0.9624, 0.834]

# %%
from cmass.infer.loaders import preprocess_Pk


def load_and_predict(summaries=['Pk0', 'Pk2'], kmax=0.1):
    # Specify data dtype
    summary = '+'.join(summaries)
    modelpath = join(save_dir, tracer, summary, f'kmax-{kmax}')
    print(modelpath)

    # Load model posterior
    p = load_posterior(modelpath)

    # Load losses
    summary_file = join(modelpath, 'summary.json')
    with open(summary_file, 'r') as f:
        history = json.load(f)

    # Preprocess observations
    xin = []
    for s in summaries:
        if s == 'Pk0':
            xs = preprocess_Pk(summ[s], kmax, monopole=True)
        else:
            xs = preprocess_Pk(summ[s], kmax, monopole=False, norm=summ['Pk0'])
        xin.append(xs)
    xin = np.array(xin).flatten()
    print(xin.shape)

    # Predict
    sampobs = p.sample(x=xin, shape=(1000,)).to('cpu')
    return sampobs, history

# %%
# Omega_m
pind = 0

f, axs = plt.subplots(1, 2, figsize=(15, 4), sharex=True)

ax = axs[0]
ax.axhline(trueparams[pind], color='C0', ls='-', label='True')
std = iva.iloc[:, pind].std()
ax.fill_between([0.1, 0.6],
                [trueparams[pind]-std]*2, [trueparams[pind] + std]*2,
                alpha=0.2, color='r', label='ivanov 2022')
std = sbpk.iloc[:, pind].std()
ax.fill_between([0.1, 0.6],
                [trueparams[pind]-std]*2, [trueparams[pind] + std]*2,
                alpha=0.2, color='g', label='SimBig')

ax2 = axs[1]

for k in [0.2, 0.3, 0.4, 0.5]:
    sampobs, hist = load_and_predict(summaries, kmax=k)

    # plot samples
    percs = np.percentile(sampobs, [16, 50, 84], axis=0)
    ax.plot(k, percs[1, pind], 'ko')
    ax.errorbar(k, percs[1, pind],
                yerr=[[percs[1, pind]-percs[0, pind]],
                      [percs[2, pind]-percs[1, pind]]],
                ecolor='k', elinewidth=1)

    # plot losses
    for j in range(len(hist)):
        ax2.plot(k, hist[j]['validation_log_probs'][-1], 'o',
                 label=f'Model {j}' if k == 0.2 else None,
                 c=f'C{j}')
ax.set(xlabel='kmax', ylabel=names[pind])
ax.legend()
ax.set_xlim(0.1, 0.6)
ax.set_title('+'.join(summaries))
ax2.set(xlabel='kmax', ylabel='final log_probability')
ax2.legend()
# Out:
# INFO:root:Sampling models with [454, 546] samples each.
# /anvil/scratch/x-mho1/cmass-ili/mtnglike/fastpm/models/halo/Pk0+Pk2/kmax-0.2
# (190,)
# Drawing 454 posterior samples: 822it [00:00, 17234.71it/s]
# Drawing 546 posterior samples: 792it [00:00, 51762.17it/s]
# INFO:root:Sampling models with [574, 426] samples each.
# /anvil/scratch/x-mho1/cmass-ili/mtnglike/fastpm/models/halo/Pk0+Pk2/kmax-0.3
# (284,)
# Drawing 574 posterior samples: 1068it [00:00, 21323.31it/s]
# Drawing 426 posterior samples: 734it [00:00, 47748.30it/s]
# INFO:root:Sampling models with [595, 405] samples each.
# /anvil/scratch/x-mho1/cmass-ili/mtnglike/fastpm/models/halo/Pk0+Pk2/kmax-0.4
# (380,)
# Drawing 595 posterior samples: 1085it [00:00, 20854.27it/s]
# Drawing 405 posterior samples: 645it [00:00, 40629.05it/s]
# INFO:root:Sampling models with [572, 428] samples each.
# /anvil/scratch/x-mho1/cmass-ili/mtnglike/fastpm/models/halo/Pk0+Pk2/kmax-0.5
# (476,)
# Drawing 572 posterior samples: 909it [00:00, 16591.12it/s]
# Drawing 428 posterior samples: 689it [00:00, 39331.41it/s]

# %%
# sigma_8
pind = 4

f, axs = plt.subplots(1, 2, figsize=(15, 4), sharex=True)

ax = axs[0]
ax.axhline(trueparams[pind], color='C0', ls='-', label='True')
std = iva.iloc[:, pind].std()
ax.fill_between([0.1, 0.6],
                [trueparams[pind]-std]*2, [trueparams[pind] + std]*2,
                alpha=0.2, color='r', label='ivanov 2022')
std = sbpk.iloc[:, pind].std()
ax.fill_between([0.1, 0.6],
                [trueparams[pind]-std]*2, [trueparams[pind] + std]*2,
                alpha=0.2, color='g', label='SimBig')

ax2 = axs[1]

for k in [0.2, 0.3, 0.4, 0.5]:
    sampobs, hist = load_and_predict(summaries, kmax=k)

    # plot samples
    percs = np.percentile(sampobs, [16, 50, 84], axis=0)
    ax.plot(k, percs[1, pind], 'ko')
    ax.errorbar(k, percs[1, pind],
                yerr=[[percs[1, pind]-percs[0, pind]],
                      [percs[2, pind]-percs[1, pind]]],
                ecolor='k', elinewidth=1)

    # plot losses
    for j in range(len(hist)):
        ax2.plot(k, hist[j]['validation_log_probs'][-1], 'o',
                 label=f'Model {j}' if k == 0.2 else None,
                 c=f'C{j}')
ax.set(xlabel='kmax', ylabel=names[pind])
ax.legend()
ax.set_xlim(0.1, 0.6)
ax.set_title('+'.join(summaries))
ax2.set(xlabel='kmax', ylabel='final log_probability')
ax2.legend()
# Out:
# INFO:root:Sampling models with [454, 546] samples each.
# /anvil/scratch/x-mho1/cmass-ili/mtnglike/fastpm/models/halo/Pk0+Pk2/kmax-0.2
# (190,)
# Drawing 454 posterior samples: 804it [00:00, 16848.89it/s]
# Drawing 546 posterior samples: 812it [00:00, 53452.43it/s]
# INFO:root:Sampling models with [574, 426] samples each.
# /anvil/scratch/x-mho1/cmass-ili/mtnglike/fastpm/models/halo/Pk0+Pk2/kmax-0.3
# (284,)
# Drawing 574 posterior samples: 1057it [00:00, 21057.28it/s]
# Drawing 426 posterior samples: 742it [00:00, 48377.51it/s]
# INFO:root:Sampling models with [595, 405] samples each.
# /anvil/scratch/x-mho1/cmass-ili/mtnglike/fastpm/models/halo/Pk0+Pk2/kmax-0.4
# (380,)
# Drawing 595 posterior samples: 1080it [00:00, 20798.77it/s]
# Drawing 405 posterior samples: 639it [00:00, 41265.61it/s]
# INFO:root:Sampling models with [572, 428] samples each.
# /anvil/scratch/x-mho1/cmass-ili/mtnglike/fastpm/models/halo/Pk0+Pk2/kmax-0.5
# (476,)
# Drawing 572 posterior samples: 881it [00:00, 16950.14it/s]
# Drawing 428 posterior samples: 674it [00:00, 38542.81it/s]

# %%
# logMmin
pind = 8

f, axs = plt.subplots(1, 2, figsize=(15, 4), sharex=True)

ax = axs[0]
ax.axhline(trueparams[pind], color='C0', ls='-', label='True')
# std = iva.iloc[:,pind].std()
# ax.fill_between([0.1, 0.6],
#                 [trueparams[pind]-std]*2, [trueparams[pind] + std]*2,
#                 alpha=0.2, color='r', label='ivanov 2022')
# std = sbpk.iloc[:,pind].std()
# ax.fill_between([0.1, 0.6],
#                 [trueparams[pind]-std]*2, [trueparams[pind] + std]*2,
#                 alpha=0.2, color='g', label='SimBig')

ax2 = axs[1]

for k in [0.2, 0.3, 0.4, 0.5]:
    sampobs, hist = load_and_predict(summaries, kmax=k)

    # plot samples
    percs = np.percentile(sampobs, [16, 50, 84], axis=0)
    ax.plot(k, percs[1, pind], 'ko')
    ax.errorbar(k, percs[1, pind],
                yerr=[[percs[1, pind]-percs[0, pind]],
                      [percs[2, pind]-percs[1, pind]]],
                ecolor='k', elinewidth=1)

    # plot losses
    for j in range(len(hist)):
        ax2.plot(k, hist[j]['validation_log_probs'][-1], 'o',
                 label=f'Model {j}' if k == 0.2 else None,
                 c=f'C{j}')
ax.set(xlabel='kmax', ylabel=names[pind])
ax.legend()
ax.set_xlim(0.1, 0.6)
ax.set_title('+'.join(summaries))
ax2.set(xlabel='kmax', ylabel='final log_probability')
ax2.legend()
# Out:
# INFO:root:Sampling models with [853, 147] samples each.
# /anvil/scratch/x-mho1/cmass-ili/mtnglike/fastpm/models/ngc_lightcone/Pk0+Pk2/kmax-0.2
# (220,)
# Drawing 853 posterior samples: 1448it [00:00, 9827.72it/s]
# Drawing 147 posterior samples: 178it [00:00, 7498.63it/s]
# INFO:root:Sampling models with [812, 188] samples each.
# /anvil/scratch/x-mho1/cmass-ili/mtnglike/fastpm/models/ngc_lightcone/Pk0+Pk2/kmax-0.3
# (332,)
# Drawing 812 posterior samples: 1433it [00:00, 9898.45it/s]
# Drawing 188 posterior samples: 210it [00:00, 8101.43it/s]
# /anvil/scratch/x-mho1/cmass-ili/mtnglike/fastpm/models/ngc_lightcone/Pk0+Pk2/kmax-0.4
# INFO:root:Sampling models with [895, 105] samples each.
# (444,)
# Drawing 895 posterior samples: 1699it [00:00, 10981.85it/s]
# Drawing 105 posterior samples: 145it [00:00, 4002.70it/s]
# /anvil/scratch/x-mho1/cmass-ili/mtnglike/fastpm/models/ngc_lightcone/Pk0+Pk2/kmax-0.5
# INFO:root:Sampling models with [953, 47] samples each.
# (556,)
# Drawing 953 posterior samples: 1811it [00:00, 11282.25it/s]
# Drawing 47 posterior samples: 66it [00:00, 1959.61it/s]

# %%
# Omega_m
pind = 0

f, axs = plt.subplots(1, 2, figsize=(15, 4), sharex=True)

ax = axs[0]
ax.axhline(trueparams[pind], color='C0', ls='-', label='True')
std = iva.iloc[:, pind].std()
ax.fill_between([-1, 3],
                [trueparams[pind]-std]*2, [trueparams[pind] + std]*2,
                alpha=0.2, color='r', label='ivanov 2022')
std = sbpk.iloc[:, pind].std()
ax.fill_between([-1, 3],
                [trueparams[pind]-std]*2, [trueparams[pind] + std]*2,
                alpha=0.2, color='g', label='SimBig')

ax2 = axs[1]

slist = [['Pk0', 'Pk2'], ['Pk0', 'Pk2', 'Qk0']]
for i, s in enumerate(slist):
    k = 0.4
    sampobs, hist = load_and_predict(s, kmax=k)

    # plot samples
    percs = np.percentile(sampobs, [16, 50, 84], axis=0)
    ax.plot(i, percs[1, pind], 'ko')
    ax.errorbar(i, percs[1, pind],
                yerr=[[percs[1, pind]-percs[0, pind]],
                      [percs[2, pind]-percs[1, pind]]],
                ecolor='k', elinewidth=1)

    # plot losses
    for j in range(len(hist)):
        y = hist[j]['validation_log_probs'][-1]
        if y > -10:
            ax2.plot(i, y, 'o',
                     label=f'Model {j}' if k == 0.2 else None,
                     c=f'C{j}')
ax.set(xlabel='summary', ylabel=names[pind])
ax.legend()
ax.set_xlim(-1, 3)
ax.set_xticks(range(len(slist)))
ax.set_xticklabels(['+'.join(s) for s in slist])
ax.set_title(f'kmax={k}')
ax2.set(xlabel='summary', ylabel='final log_probability')
ax2.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 7
#       4 f, axs = plt.subplots(1,2, figsize=(15,4), sharex=True)
#       6 ax = axs[0]
# ----> 7 ax.axhline(trueparams[pind], color='C0', ls='-', label='True')
#       8 std = iva.iloc[:,pind].std()
#       9 ax.fill_between([-1, 3],
#      10                 [trueparams[pind]-std]*2, [trueparams[pind] + std]*2,
#      11                 alpha=0.2, color='r', label='ivanov 2022')
#
# NameError: name 'trueparams' is not defined

# %%
# sigma8
pind = 4

f, axs = plt.subplots(1, 2, figsize=(15, 4), sharex=True)

ax = axs[0]
ax.axhline(trueparams[pind], color='C0', ls='-', label='True')
std = iva.iloc[:, pind].std()
ax.fill_between([-1, 3],
                [trueparams[pind]-std]*2, [trueparams[pind] + std]*2,
                alpha=0.2, color='r', label='ivanov 2022')
std = sbpk.iloc[:, pind].std()
ax.fill_between([-1, 3],
                [trueparams[pind]-std]*2, [trueparams[pind] + std]*2,
                alpha=0.2, color='g', label='SimBig')

ax2 = axs[1]

slist = [['Pk0'], ['Pk0', 'Pk2'], ['Pk0', 'Pk2', 'Pk4']]
for i, s in enumerate(slist):
    k = 0.4
    sampobs, hist = load_and_predict(s, kmax=k)

    # plot samples
    percs = np.percentile(sampobs, [16, 50, 84], axis=0)
    ax.plot(i, percs[1, pind], 'ko')
    ax.errorbar(i, percs[1, pind],
                yerr=[[percs[1, pind]-percs[0, pind]],
                      [percs[2, pind]-percs[1, pind]]],
                ecolor='k', elinewidth=1)

    # plot losses
    for j in range(len(hist)):
        y = hist[j]['validation_log_probs'][-1]
        if y > -10:
            ax2.plot(i, y, 'o',
                     label=f'Model {j}' if k == 0.2 else None,
                     c=f'C{j}')
ax.set(xlabel='summary', ylabel=names[pind])
ax.legend()
ax.set_xlim(-1, 3)
ax.set_xticks(range(len(slist)))
ax.set_xticklabels(['+'.join(s) for s in slist])
ax.set_title(f'kmax={k}')
ax2.set(xlabel='summary', ylabel='final log_probability')
ax2.legend()
# Out:
# INFO:root:Sampling models with [874, 126] samples each.
# /anvil/scratch/x-mho1/cmass-ili/mtnglike/fastpm/models/ngc_lightcone/Pk0/kmax-0.4
# (222,)
# Drawing 874 posterior samples: 1372it [00:00, 8680.19it/s]
# Drawing 126 posterior samples: 128it [00:00, 3677.93it/s]
# INFO:root:Sampling models with [895, 105] samples each.
# /anvil/scratch/x-mho1/cmass-ili/mtnglike/fastpm/models/ngc_lightcone/Pk0+Pk2/kmax-0.4
# (444,)
# Drawing 895 posterior samples: 1714it [00:00, 10559.12it/s]
# Drawing 105 posterior samples: 136it [00:00, 3783.69it/s]
# INFO:root:Sampling models with [1000, 0] samples each.
# /anvil/scratch/x-mho1/cmass-ili/mtnglike/fastpm/models/ngc_lightcone/Pk0+Pk2+Pk4/kmax-0.4
# (666,)
# Drawing 1000 posterior samples: 1674it [00:00, 9345.91it/s]

# %%
# logMmin
pind = 8

f, axs = plt.subplots(1, 2, figsize=(15, 4), sharex=True)

ax = axs[0]
ax.axhline(trueparams[pind], color='C0', ls='-', label='True')
# std = iva.iloc[:,pind].std()
# ax.fill_between([-1, 3],
#                 [trueparams[pind]-std]*2, [trueparams[pind] + std]*2,
#                 alpha=0.2, color='r', label='ivanov 2022')
# std = sbpk.iloc[:,pind].std()
# ax.fill_between([-1, 3],
#                 [trueparams[pind]-std]*2, [trueparams[pind] + std]*2,
#                 alpha=0.2, color='g', label='SimBig')

ax2 = axs[1]

slist = [['Pk0'], ['Pk0', 'Pk2'], ['Pk0', 'Pk2', 'Pk4']]
for i, s in enumerate(slist):
    k = 0.4
    sampobs, hist = load_and_predict(s, kmax=k)

    # plot samples
    percs = np.percentile(sampobs, [16, 50, 84], axis=0)
    ax.plot(i, percs[1, pind], 'ko')
    ax.errorbar(i, percs[1, pind],
                yerr=[[percs[1, pind]-percs[0, pind]],
                      [percs[2, pind]-percs[1, pind]]],
                ecolor='k', elinewidth=1)

    # plot losses
    for j in range(len(hist)):
        y = hist[j]['validation_log_probs'][-1]
        if y > -10:
            ax2.plot(i, y, 'o',
                     label=f'Model {j}' if k == 0.2 else None,
                     c=f'C{j}')
ax.set(xlabel='summary', ylabel=names[pind])
ax.legend()
ax.set_xlim(-1, 3)
ax.set_xticks(range(len(slist)))
ax.set_xticklabels(['+'.join(s) for s in slist])
ax.set_title(f'kmax={k}')
ax2.set(xlabel='summary', ylabel='final log_probability')
ax2.legend()
# Out:
# INFO:root:Sampling models with [874, 126] samples each.
# /anvil/scratch/x-mho1/cmass-ili/mtnglike/fastpm/models/ngc_lightcone/Pk0/kmax-0.4
# (222,)
# Drawing 874 posterior samples: 1362it [00:00, 9113.50it/s]
# Drawing 126 posterior samples:  89%|████████▉ | 112/126 [00:00<00:00, 3231.34it/s]
# INFO:root:Sampling models with [895, 105] samples each.
# /anvil/scratch/x-mho1/cmass-ili/mtnglike/fastpm/models/ngc_lightcone/Pk0+Pk2/kmax-0.4
# (444,)
# Drawing 895 posterior samples: 1707it [00:00, 10855.35it/s]
# Drawing 105 posterior samples: 110it [00:00, 4678.44it/s]
# /anvil/scratch/x-mho1/cmass-ili/mtnglike/fastpm/models/ngc_lightcone/Pk0+Pk2+Pk4/kmax-0.4
# INFO:root:Sampling models with [1000, 0] samples each.
# (666,)
# Drawing 1000 posterior samples: 1709it [00:00, 9988.34it/s]

# %% [markdown]
# ## Measure constraining power

# %% [markdown]
# ## Scratch
